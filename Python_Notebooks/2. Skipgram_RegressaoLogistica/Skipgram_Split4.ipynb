# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import torch

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
def Accuracy(prediction, observation):
  prediction = prediction[:,1]
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  correct = (prediction_class == observation).float().sum()
  accuracy = correct/prediction_class.shape[0]
  return float(accuracy.cpu())

def Precision(prediction, observation):
  prediction = prediction[:,1]
  res = []
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  for label in [0, 1]:
    correct = (prediction_class[prediction_class == label] == observation[prediction_class == label]).float().sum()
    precision = correct/prediction_class[prediction_class == label].shape[0]
    res.append(float(precision.cpu()))
  return res

def Recall(prediction, observation):
  prediction = prediction[:,1]
  res = []
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  for label in [0, 1]:
    correct = (prediction_class[observation == label] == observation[observation == label]).float().sum()
    recall = correct/prediction_class[observation == label].shape[0]
    res.append(float(recall.cpu()))
  return res

# %%
n_split = 4

# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open('/content/drive/My Drive/Data Master/X_train_final', 'rb') as file:
    X_train = pickle.load(file)

with open('/content/drive/My Drive/Data Master/Y_train_final', 'rb') as file:
    Y_train = pickle.load(file)

with open('/content/drive/My Drive/Data Master/X_test_final', 'rb') as file:
    X_test = pickle.load(file)

with open('/content/drive/My Drive/Data Master/Y_test_final', 'rb') as file:
    Y_test = pickle.load(file)

with open('/content/drive/My Drive/Data Master/word_index_final', 'rb') as file:
    word_index = pickle.load(file)

with open('/content/drive/My Drive/Data Master/train_index_final_split_' + str(n_split), 'rb') as file:
    train_index = pickle.load(file)

with open('/content/drive/My Drive/Data Master/valid_index_final_split_' + str(n_split), 'rb') as file:
    valid_index = pickle.load(file)

# %%
inv_word_index = {ix : w for w, ix in word_index.items()}

# %%
errors = []
embeddings_index = {}
f = open('/content/drive/My Drive/Data Master/skip_s50.txt')
for line in f:
    values = line.split()
    word = values[0]
    try:
      coefs = np.asarray(values[1:], dtype='float32')
    except:
      errors.append(line)
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 929595 word vectors.

# %%
print(len(embeddings_index))
print(len(errors))
# Out:
# 929595
# 4

# %%
EMBEDDING_DIM = 50
errors_2 = []
nomatchs = []

X_train_matrix = np.zeros((len(X_train), EMBEDDING_DIM))
X_test_matrix = np.zeros((len(X_test), EMBEDDING_DIM))

# %%
for i, x in enumerate(X_train):
  for w in x:
    embedding_vector = embeddings_index.get(inv_word_index[w])
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        try:
          X_train_matrix[i] += embedding_vector
        except:
          errors_2.append([word, len(embedding_vector), embedding_vector])
    else:
      nomatchs.append(word)

# %%
for i, x in enumerate(X_test):
  for w in x:
    embedding_vector = embeddings_index.get(inv_word_index[w])
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        try:
          X_test_matrix[i] += embedding_vector
        except:
          errors_2.append([word, len(embedding_vector), embedding_vector])
    else:
      nomatchs.append(word)

# %%
X_train_matrix.shape
# Out:
# (888, 50)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
input_dim = X_train_matrix.shape[1]
input_dim
# Out:
# 50

# %%
class LogisticRegression (nn.Module):

  def __init__(self):
    super(LogisticRegression, self).__init__()

    self.fc1 = nn.Linear(input_dim, 2)
                                
    self.softmax = nn.Softmax(dim=1)

  def forward(self, x):
    x = F.normalize(x)
    y = self.softmax(self.fc1(x))

    return y

# %%
X_train_tensor = torch.from_numpy(X_train_matrix[train_index]).float()
Y_train_tensor = torch.LongTensor(np.array(Y_train[train_index]))

X_valid_tensor = torch.from_numpy(X_train_matrix[valid_index]).float()
Y_valid_tensor = torch.LongTensor(np.array(Y_train[valid_index]))

X_test_tensor = torch.from_numpy(X_test_matrix).float()
Y_test_tensor = torch.LongTensor(np.array(Y_test))

# %%
model = LogisticRegression()

# %%
torch.manual_seed(0)
np.random.seed(0)

# %%
import torch.optim as optim
optimizer = optim.AdamW(model.parameters(), lr=0.01)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
weights = [sum(Y_train)/len(Y_train), 1-sum(Y_train)/len(Y_train)]
class_weights = torch.FloatTensor(weights)
class_weights
# Out:
# tensor([0.1734, 0.8266])

# %%
criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
patience = 20
early_stopping = EarlyStopping(patience=patience, verbose=True)


for i in range(1000):
  model.train()
  optimizer.zero_grad()
  prediction = model(X_train_tensor)
  loss = criterion(prediction, Y_train_tensor)
  loss.backward()
  optimizer.step()

  accuracy = Accuracy(prediction, Y_train_tensor)

  model.eval()

  val_prediction = model(X_valid_tensor)
  test_prediction = model(X_test_tensor)
  val_loss = criterion(val_prediction, Y_valid_tensor)
  test_loss = criterion(test_prediction, Y_test_tensor)

  val_accuracy = Accuracy(val_prediction, Y_valid_tensor)
  test_accuracy = Accuracy(test_prediction, Y_test_tensor)

  early_stopping(val_loss, model)

  if early_stopping.early_stop:
    print("Early stopping")
    break

  print(i, float(loss.cpu()), accuracy, float(val_loss.cpu()), val_accuracy, float(test_loss.cpu()), test_accuracy)

  scheduler.step(val_loss)

model.load_state_dict(torch.load('checkpoint.pt'))
# Out:
# Validation loss decreased (inf --> 0.692374).  Saving model ...
# 0 0.6943894624710083 0.17323943972587585 0.6923736333847046 0.7247191071510315 0.6932754516601562 0.682414710521698
# Validation loss decreased (0.692374 --> 0.690954).  Saving model ...
# 1 0.6930996775627136 0.6507042050361633 0.6909543871879578 0.8426966071128845 0.6921858787536621 0.847769021987915
# Validation loss decreased (0.690954 --> 0.689523).  Saving model ...
# 2 0.6918512582778931 0.8295774459838867 0.6895228028297424 0.8651685118675232 0.6911998987197876 0.847769021987915
# Validation loss decreased (0.689523 --> 0.688084).  Saving model ...
# 3 0.6905986070632935 0.8521126508712769 0.6880837678909302 0.8539325594902039 0.6902690529823303 0.8451443314552307
# Validation loss decreased (0.688084 --> 0.686652).  Saving model ...
# 4 0.6893416047096252 0.8450704216957092 0.6866522431373596 0.7808988690376282 0.6893642544746399 0.7716535329818726
# Validation loss decreased (0.686652 --> 0.685235).  Saving model ...
# 5 0.6880911588668823 0.7859154939651489 0.6852350234985352 0.7191011309623718 0.6884576082229614 0.6876640319824219
# Validation loss decreased (0.685235 --> 0.683828).  Saving model ...
# 6 0.6868511438369751 0.719718337059021 0.6838280558586121 0.7078651785850525 0.6875271201133728 0.6719160079956055
# Validation loss decreased (0.683828 --> 0.682427).  Saving model ...
# 7 0.6856175065040588 0.6915493011474609 0.6824274063110352 0.7191011309623718 0.6865649819374084 0.6771653294563293
# Validation loss decreased (0.682427 --> 0.681033).  Saving model ...
# 8 0.6843854188919067 0.716901421546936 0.6810331344604492 0.7359550595283508 0.6855804920196533 0.7139107584953308
# Validation loss decreased (0.681033 --> 0.679648).  Saving model ...
# 9 0.6831551194190979 0.7450703978538513 0.6796478629112244 0.7808988690376282 0.6845927238464355 0.7454068064689636
# Validation loss decreased (0.679648 --> 0.678272).  Saving model ...
# 10 0.6819329857826233 0.7760563492774963 0.6782721281051636 0.7865168452262878 0.6836161017417908 0.7559055089950562
# Validation loss decreased (0.678272 --> 0.676905).  Saving model ...
# 11 0.6807190179824829 0.7957746386528015 0.6769048571586609 0.7921348214149475 0.6826617121696472 0.7637795209884644
# Validation loss decreased (0.676905 --> 0.675544).  Saving model ...
# 12 0.6795116662979126 0.8014084696769714 0.6755443215370178 0.7865168452262878 0.6817328929901123 0.7637795209884644
# Validation loss decreased (0.675544 --> 0.674191).  Saving model ...
# 13 0.6783097982406616 0.800000011920929 0.6741909384727478 0.7865168452262878 0.6808282136917114 0.7585301995277405
# Validation loss decreased (0.674191 --> 0.672847).  Saving model ...
# 14 0.6771134734153748 0.8028169274330139 0.6728472113609314 0.7921348214149475 0.6799412369728088 0.7532808184623718
# Validation loss decreased (0.672847 --> 0.671514).  Saving model ...
# 15 0.6759234666824341 0.7873239517211914 0.671514093875885 0.7752808928489685 0.6790630221366882 0.7427821755409241
# Validation loss decreased (0.671514 --> 0.670192).  Saving model ...
# 16 0.6747420430183411 0.780281662940979 0.6701923608779907 0.7752808928489685 0.6781851053237915 0.7349081635475159
# Validation loss decreased (0.670192 --> 0.668880).  Saving model ...
# 17 0.6735683679580688 0.7690140604972839 0.6688799262046814 0.7752808928489685 0.6773006916046143 0.7322834730148315
# Validation loss decreased (0.668880 --> 0.667576).  Saving model ...
# 18 0.6724020838737488 0.7690140604972839 0.667576253414154 0.7752808928489685 0.6764090061187744 0.7401574850082397
# Validation loss decreased (0.667576 --> 0.666282).  Saving model ...
# 19 0.6712421178817749 0.7690140604972839 0.6662824749946594 0.7752808928489685 0.6755163073539734 0.7454068064689636
# Validation loss decreased (0.666282 --> 0.665000).  Saving model ...
# 20 0.6700897216796875 0.783098578453064 0.6649995446205139 0.7865168452262878 0.6746298670768738 0.7532808184623718
# Validation loss decreased (0.665000 --> 0.663727).  Saving model ...
# 21 0.668945848941803 0.7915493249893188 0.6637269258499146 0.7921348214149475 0.6737576127052307 0.7585301995277405
# Validation loss decreased (0.663727 --> 0.662466).  Saving model ...
# 22 0.6678104400634766 0.794366180896759 0.6624659299850464 0.7921348214149475 0.6729024648666382 0.7585301995277405
# Validation loss decreased (0.662466 --> 0.661216).  Saving model ...
# 23 0.6666823625564575 0.794366180896759 0.661215603351593 0.7921348214149475 0.6720651984214783 0.7585301995277405
# Validation loss decreased (0.661216 --> 0.659977).  Saving model ...
# 75 0.6193673014640808 0.8014084696769714 0.6108861565589905 0.7865168452262878 0.6378809809684753 0.7795275449752808
# Validation loss decreased (0.610886 --> 0.610157).  Saving model ...
# 76 0.61865234375 0.8014084696769714 0.6101572513580322 0.7865168452262878 0.6373752355575562 0.7795275449752808
# Validation loss decreased (0.610157 --> 0.609435).  Saving model ...
# 77 0.6179443597793579 0.8014084696769714 0.6094349026679993 0.7865168452262878 0.6368726491928101 0.7847769260406494
# Validation loss decreased (0.609435 --> 0.608719).  Saving model ...
# 78 0.6172417998313904 0.8014084696769714 0.6087190508842468 0.7865168452262878 0.6363736987113953 0.7847769260406494
# Validation loss decreased (0.608719 --> 0.608010).  Saving model ...
# 79 0.6165459156036377 0.8028169274330139 0.6080102920532227 0.7865168452262878 0.635879635810852 0.7847769260406494
# Validation loss decreased (0.608010 --> 0.607308).  Saving model ...
# 80 0.61585533618927 0.8028169274330139 0.6073079109191895 0.7865168452262878 0.6353910565376282 0.787401556968689
# Validation loss decreased (0.607308 --> 0.606613).  Saving model ...
# 81 0.6151708364486694 0.8042253255844116 0.6066126823425293 0.7865168452262878 0.6349062919616699 0.787401556968689
# Validation loss decreased (0.606613 --> 0.605924).  Saving model ...
# 82 0.6144919395446777 0.8042253255844116 0.6059238314628601 0.7865168452262878 0.6344264149665833 0.787401556968689
# Validation loss decreased (0.605924 --> 0.605241).  Saving model ...
# 83 0.6138185858726501 0.8042253255844116 0.605241060256958 0.7865168452262878 0.6339501142501831 0.787401556968689
# Validation loss decreased (0.605241 --> 0.604564).  Saving model ...
# 84 0.6131510734558105 0.8042253255844116 0.6045640110969543 0.7865168452262878 0.6334770321846008 0.787401556968689
# Validation loss decreased (0.604564 --> 0.603893).  Saving model ...
# 85 0.6124889254570007 0.8042253255844116 0.6038927435874939 0.7921348214149475 0.6330071091651917 0.787401556968689
# Validation loss decreased (0.603893 --> 0.603227).  Saving model ...
# 86 0.6118316054344177 0.8042253255844116 0.603227436542511 0.7865168452262878 0.6325414180755615 0.787401556968689
# Validation loss decreased (0.603227 --> 0.602568).  Saving model ...
# 87 0.6111802458763123 0.8056337833404541 0.6025683879852295 0.7865168452262878 0.6320802569389343 0.787401556968689
# Validation loss decreased (0.602568 --> 0.601915).  Saving model ...
# 88 0.6105347871780396 0.8056337833404541 0.6019154191017151 0.7921348214149475 0.6316226124763489 0.787401556968689
# Validation loss decreased (0.601915 --> 0.601268).  Saving model ...
# 89 0.6098935604095459 0.8056337833404541 0.601268470287323 0.7921348214149475 0.6311694979667664 0.787401556968689
# Validation loss decreased (0.601268 --> 0.600627).  Saving model ...
# 90 0.6092577576637268 0.8056337833404541 0.6006269454956055 0.7921348214149475 0.630719780921936 0.7900262475013733
# Validation loss decreased (0.600627 --> 0.599991).  Saving model ...
# 91 0.6086277365684509 0.8070422410964966 0.599990725517273 0.7921348214149475 0.6302725672721863 0.7926509380340576
# Validation loss decreased (0.599991 --> 0.599360).  Saving model ...
# 92 0.6080023646354675 0.8070422410964966 0.5993595123291016 0.7921348214149475 0.6298292279243469 0.7926509380340576
# Validation loss decreased (0.599360 --> 0.598734).  Saving model ...
# 93 0.6073817014694214 0.8070422410964966 0.5987340211868286 0.7921348214149475 0.6293889880180359 0.7952755689620972
# Validation loss decreased (0.598734 --> 0.598114).  Saving model ...
# 94 0.6067661046981812 0.8070422410964966 0.5981137752532959 0.7921348214149475 0.6289527416229248 0.7952755689620972
# Validation loss decreased (0.598114 --> 0.597499).  Saving model ...
# 95 0.6061553359031677 0.8084506988525391 0.5974991321563721 0.7921348214149475 0.6285203099250793 0.7952755689620972
# Validation loss decreased (0.597499 --> 0.596890).  Saving model ...
# 96 0.6055498719215393 0.8084506988525391 0.5968896746635437 0.7921348214149475 0.6280913352966309 0.7952755689620972
# Validation loss decreased (0.596890 --> 0.596285).  Saving model ...
# 97 0.6049486398696899 0.8084506988525391 0.5962852239608765 0.7921348214149475 0.6276655793190002 0.7952755689620972
# Validation loss decreased (0.596285 --> 0.595686).  Saving model ...
# 98 0.6043524146080017 0.8098591566085815 0.5956855416297913 0.7921348214149475 0.6272426843643188 0.7952755689620972
# Validation loss decreased (0.595686 --> 0.595091).  Saving model ...
# 99 0.603760838508606 0.8098591566085815 0.5950908660888672 0.7921348214149475 0.6268226504325867 0.7952755689620972
# Validation loss decreased (0.595091 --> 0.594501).  Saving model ...
# 100 0.6031734943389893 0.811267614364624 0.5945006608963013 0.7921348214149475 0.6264055967330933 0.7952755689620972
# Validation loss decreased (0.594501 --> 0.593916).  Saving model ...
# 101 0.6025917530059814 0.811267614364624 0.5939158201217651 0.7921348214149475 0.6259925961494446 0.7952755689620972
# Validation loss decreased (0.593916 --> 0.593336).  Saving model ...
# 102 0.6020132899284363 0.8154929280281067 0.5933358073234558 0.7921348214149475 0.625582218170166 0.7952755689620972
# Validation loss decreased (0.593336 --> 0.592760).  Saving model ...
# 103 0.6014396548271179 0.8154929280281067 0.592760443687439 0.7921348214149475 0.6251754760742188 0.7952755689620972
# Validation loss decreased (0.592760 --> 0.592190).  Saving model ...
# 104 0.6008702516555786 0.8154929280281067 0.5921897888183594 0.7921348214149475 0.6247712969779968 0.7926509380340576
# Validation loss decreased (0.592190 --> 0.591623).  Saving model ...
# 105 0.6003053188323975 0.8154929280281067 0.5916234850883484 0.7921348214149475 0.624370276927948 0.7926509380340576
# Validation loss decreased (0.591623 --> 0.591062).  Saving model ...
# 106 0.5997454524040222 0.8169013857841492 0.5910615921020508 0.7977527976036072 0.6239719986915588 0.7900262475013733
# Validation loss decreased (0.591062 --> 0.590504).  Saving model ...
# 107 0.5991889238357544 0.8169013857841492 0.5905041098594666 0.7977527976036072 0.6235764026641846 0.7900262475013733
# Validation loss decreased (0.590504 --> 0.589951).  Saving model ...
# 108 0.5986369252204895 0.8169013857841492 0.5899508595466614 0.7977527976036072 0.6231839060783386 0.7900262475013733
# Validation loss decreased (0.589951 --> 0.589402).  Saving model ...
# 109 0.598088800907135 0.8169013857841492 0.5894021987915039 0.7977527976036072 0.6227943897247314 0.7900262475013733
# Validation loss decreased (0.589402 --> 0.588858).  Saving model ...
# 110 0.5975447297096252 0.8169013857841492 0.5888583064079285 0.7977527976036072 0.6224077939987183 0.7900262475013733
# Validation loss decreased (0.588858 --> 0.588318).  Saving model ...
# 111 0.5970050096511841 0.8169013857841492 0.5883181691169739 0.7977527976036072 0.6220239400863647 0.7926509380340576
# Validation loss decreased (0.588318 --> 0.587782).  Saving model ...
# 112 0.5964693427085876 0.8169013857841492 0.5877821445465088 0.7977527976036072 0.6216425895690918 0.7926509380340576
# Validation loss decreased (0.587782 --> 0.587250).  Saving model ...
# 113 0.5959374308586121 0.8169013857841492 0.5872501730918884 0.7977527976036072 0.6212639212608337 0.7926509380340576
# Validation loss decreased (0.587250 --> 0.586722).  Saving model ...
# 114 0.5954093933105469 0.8169013857841492 0.5867223143577576 0.7977527976036072 0.6208881735801697 0.7926509380340576
# Validation loss decreased (0.586722 --> 0.586199).  Saving model ...
# 115 0.5948857069015503 0.8183098435401917 0.5861985087394714 0.7977527976036072 0.6205143928527832 0.7926509380340576
# Validation loss decreased (0.586199 --> 0.585679).  Saving model ...
# 116 0.594365656375885 0.8183098435401917 0.5856786370277405 0.7977527976036072 0.6201440095901489 0.7926509380340576
# Validation loss decreased (0.585679 --> 0.585163).  Saving model ...
# 117 0.593849241733551 0.8197183012962341 0.5851627588272095 0.7977527976036072 0.6197762489318848 0.7926509380340576
# Validation loss decreased (0.585163 --> 0.584651).  Saving model ...
# 118 0.5933362245559692 0.8197183012962341 0.5846507549285889 0.7977527976036072 0.6194105744361877 0.7952755689620972
# Validation loss decreased (0.584651 --> 0.584143).  Saving model ...
# 119 0.5928272604942322 0.8197183012962341 0.5841427445411682 0.7977527976036072 0.6190474033355713 0.7952755689620972
# Validation loss decreased (0.584143 --> 0.583638).  Saving model ...
# 120 0.592322587966919 0.8197183012962341 0.5836380124092102 0.7977527976036072 0.618686854839325 0.7926509380340576
# Validation loss decreased (0.583638 --> 0.583137).  Saving model ...
# 121 0.5918208360671997 0.8183098435401917 0.5831372141838074 0.7977527976036072 0.6183285117149353 0.7926509380340576
# Validation loss decreased (0.583137 --> 0.582640).  Saving model ...
# 122 0.5913228988647461 0.8183098435401917 0.5826401710510254 0.7921348214149475 0.6179730296134949 0.7926509380340576
# Validation loss decreased (0.582640 --> 0.582147).  Saving model ...
# 123 0.5908282995223999 0.8197183012962341 0.5821468830108643 0.7921348214149475 0.6176201105117798 0.7926509380340576
# Validation loss decreased (0.582147 --> 0.581657).  Saving model ...
# 124 0.5903372764587402 0.8211267590522766 0.5816571712493896 0.7977527976036072 0.6172695159912109 0.7926509380340576
# Validation loss decreased (0.581657 --> 0.581171).  Saving model ...
# 125 0.5898503065109253 0.8225352168083191 0.5811710357666016 0.7977527976036072 0.6169208288192749 0.7952755689620972
# Validation loss decreased (0.581171 --> 0.580688).  Saving model ...
# 160 0.5747310519218445 0.8422535061836243 0.5661029815673828 0.8089887499809265 0.6060363054275513 0.7952755689620972
# Validation loss decreased (0.566103 --> 0.565721).  Saving model ...
# 161 0.5743479132652283 0.8422535061836243 0.5657212138175964 0.8089887499809265 0.605758786201477 0.7952755689620972
# Validation loss decreased (0.565721 --> 0.565342).  Saving model ...
# 162 0.573967456817627 0.8422535061836243 0.5653418898582458 0.8089887499809265 0.6054823994636536 0.7952755689620972
# Validation loss decreased (0.565342 --> 0.564965).  Saving model ...
# 163 0.5735893845558167 0.8436619639396667 0.5649647116661072 0.8089887499809265 0.6052079200744629 0.7952755689620972
# Validation loss decreased (0.564965 --> 0.564590).  Saving model ...
# 164 0.5732137560844421 0.8450704216957092 0.5645896792411804 0.8089887499809265 0.6049348711967468 0.7979002594947815
# Validation loss decreased (0.564590 --> 0.564217).  Saving model ...
# 165 0.5728402733802795 0.8450704216957092 0.5642174482345581 0.8089887499809265 0.604663610458374 0.7979002594947815
# Validation loss decreased (0.564217 --> 0.563847).  Saving model ...
# 166 0.5724692940711975 0.8450704216957092 0.5638473629951477 0.8089887499809265 0.6043934226036072 0.7979002594947815
# Validation loss decreased (0.563847 --> 0.563479).  Saving model ...
# 167 0.5721004009246826 0.8450704216957092 0.5634792447090149 0.8146067261695862 0.6041256189346313 0.7979002594947815
# Validation loss decreased (0.563479 --> 0.563114).  Saving model ...
# 168 0.5717336535453796 0.8450704216957092 0.5631135106086731 0.8146067261695862 0.6038587689399719 0.7979002594947815
# Validation loss decreased (0.563114 --> 0.562750).  Saving model ...
# 169 0.5713698267936707 0.8450704216957092 0.5627500414848328 0.8146067261695862 0.603593647480011 0.7979002594947815
# Validation loss decreased (0.562750 --> 0.562389).  Saving model ...
# 170 0.571007251739502 0.8450704216957092 0.5623887181282043 0.8146067261695862 0.6033301949501038 0.7979002594947815
# Validation loss decreased (0.562389 --> 0.562030).  Saving model ...
# 171 0.5706478953361511 0.8450704216957092 0.5620297193527222 0.8146067261695862 0.6030685901641846 0.7979002594947815
# Validation loss decreased (0.562030 --> 0.561672).  Saving model ...
# 172 0.5702905058860779 0.8450704216957092 0.5616724491119385 0.8146067261695862 0.6028078198432922 0.7979002594947815
# Validation loss decreased (0.561672 --> 0.561318).  Saving model ...
# 173 0.5699346661567688 0.8464788794517517 0.5613176226615906 0.8146067261695862 0.6025485992431641 0.8005249500274658
# Validation loss decreased (0.561318 --> 0.560965).  Saving model ...
# 174 0.5695814490318298 0.8478873372077942 0.5609647631645203 0.8146067261695862 0.6022908687591553 0.8031495809555054
# Validation loss decreased (0.560965 --> 0.560614).  Saving model ...
# 175 0.569230318069458 0.8478873372077942 0.5606141686439514 0.8146067261695862 0.6020345091819763 0.8031495809555054
# Validation loss decreased (0.560614 --> 0.560266).  Saving model ...
# 176 0.5688809752464294 0.8478873372077942 0.5602655410766602 0.8146067261695862 0.6017802357673645 0.8031495809555054
# Validation loss decreased (0.560266 --> 0.559919).  Saving model ...
# 211 0.5578626394271851 0.8549295663833618 0.549223005771637 0.8202247023582458 0.593687117099762 0.8110235929489136
# Validation loss decreased (0.549223 --> 0.548937).  Saving model ...
# 212 0.557578980922699 0.8549295663833618 0.5489369034767151 0.8202247023582458 0.5934771299362183 0.8110235929489136
# Validation loss decreased (0.548937 --> 0.548653).  Saving model ...
# 213 0.5572964549064636 0.8549295663833618 0.5486525893211365 0.8202247023582458 0.5932682156562805 0.8110235929489136
# Validation loss decreased (0.548653 --> 0.548370).  Saving model ...
# 214 0.5570156574249268 0.8549295663833618 0.5483698844909668 0.8202247023582458 0.5930606126785278 0.8110235929489136
# Validation loss decreased (0.548370 --> 0.548088).  Saving model ...
# 215 0.5567362904548645 0.8549295663833618 0.5480883121490479 0.8202247023582458 0.5928537249565125 0.8110235929489136
# Validation loss decreased (0.548088 --> 0.547808).  Saving model ...
# 216 0.556458055973053 0.8549295663833618 0.5478084087371826 0.8202247023582458 0.5926478505134583 0.8110235929489136
# Validation loss decreased (0.547808 --> 0.547530).  Saving model ...
# 217 0.5561817288398743 0.8549295663833618 0.5475297570228577 0.8202247023582458 0.59244304895401 0.8110235929489136
# Validation loss decreased (0.547530 --> 0.547252).  Saving model ...
# 218 0.5559060573577881 0.8549295663833618 0.5472524762153625 0.8202247023582458 0.5922397375106812 0.8110235929489136
# Validation loss decreased (0.547252 --> 0.546977).  Saving model ...
# 219 0.555633008480072 0.8549295663833618 0.5469768643379211 0.8258426785469055 0.5920369029045105 0.8110235929489136
# Validation loss decreased (0.546977 --> 0.546702).  Saving model ...
# 220 0.5553608536720276 0.8549295663833618 0.5467023849487305 0.8258426785469055 0.5918352603912354 0.8136482834815979
# Validation loss decreased (0.546702 --> 0.546430).  Saving model ...
# 221 0.555090069770813 0.8549295663833618 0.5464295744895935 0.8258426785469055 0.5916347503662109 0.8136482834815979
# Validation loss decreased (0.546430 --> 0.546158).  Saving model ...
# 222 0.5548207759857178 0.8549295663833618 0.5461578965187073 0.8258426785469055 0.5914352536201477 0.8136482834815979
# Validation loss decreased (0.546158 --> 0.545888).  Saving model ...
# 223 0.5545530319213867 0.8549295663833618 0.5458876490592957 0.8258426785469055 0.5912362933158875 0.8136482834815979
# Validation loss decreased (0.545888 --> 0.545619).  Saving model ...
# 224 0.5542864203453064 0.8549295663833618 0.5456185936927795 0.8258426785469055 0.5910386443138123 0.8188976645469666
# Validation loss decreased (0.545619 --> 0.545351).  Saving model ...
# 225 0.5540212392807007 0.8535211086273193 0.5453509092330933 0.8258426785469055 0.5908417701721191 0.8188976645469666
# Validation loss decreased (0.545351 --> 0.545085).  Saving model ...
# 226 0.5537577271461487 0.8535211086273193 0.5450848340988159 0.8258426785469055 0.5906463861465454 0.8188976645469666
# Validation loss decreased (0.545085 --> 0.544820).  Saving model ...
# 227 0.5534956455230713 0.8535211086273193 0.5448200106620789 0.8258426785469055 0.5904513597488403 0.8188976645469666
# Validation loss decreased (0.544820 --> 0.544556).  Saving model ...
# 228 0.5532347559928894 0.8535211086273193 0.5445562601089478 0.8258426785469055 0.5902577638626099 0.8188976645469666
# Validation loss decreased (0.544556 --> 0.544294).  Saving model ...
# 229 0.5529749393463135 0.8549295663833618 0.5442937612533569 0.8258426785469055 0.5900647044181824 0.8188976645469666
# Validation loss decreased (0.544294 --> 0.544033).  Saving model ...
# 230 0.552716851234436 0.8549295663833618 0.544032871723175 0.8258426785469055 0.5898729562759399 0.8188976645469666
# Validation loss decreased (0.544033 --> 0.543773).  Saving model ...
# 231 0.5524595379829407 0.8549295663833618 0.5437731742858887 0.8258426785469055 0.5896821022033691 0.8215222954750061
# Validation loss decreased (0.543773 --> 0.543515).  Saving model ...
# 232 0.5522040724754333 0.8549295663833618 0.5435145497322083 0.8258426785469055 0.5894920825958252 0.8215222954750061
# Validation loss decreased (0.543515 --> 0.543257).  Saving model ...
# 233 0.5519495010375977 0.8549295663833618 0.5432572364807129 0.8258426785469055 0.5893031358718872 0.8215222954750061
# Validation loss decreased (0.543257 --> 0.543001).  Saving model ...
# 234 0.5516967177391052 0.8549295663833618 0.5430014133453369 0.8314606547355652 0.5891146659851074 0.8215222954750061
# Validation loss decreased (0.543001 --> 0.542747).  Saving model ...
# 235 0.5514452457427979 0.8549295663833618 0.5427467226982117 0.8314606547355652 0.5889272093772888 0.8215222954750061
# Validation loss decreased (0.542747 --> 0.542493).  Saving model ...
# 236 0.5511942505836487 0.8549295663833618 0.5424927473068237 0.8314606547355652 0.5887410044670105 0.8215222954750061
# Validation loss decreased (0.542493 --> 0.542241).  Saving model ...
# 237 0.5509452819824219 0.8563380241394043 0.5422408580780029 0.8314606547355652 0.5885552167892456 0.8215222954750061
# Validation loss decreased (0.542241 --> 0.541990).  Saving model ...
# 238 0.5506973266601562 0.8563380241394043 0.5419896245002747 0.8314606547355652 0.5883707404136658 0.8215222954750061
# Validation loss decreased (0.541990 --> 0.541740).  Saving model ...
# 239 0.5504505634307861 0.8563380241394043 0.5417397022247314 0.8314606547355652 0.5881870985031128 0.8215222954750061
# Validation loss decreased (0.541740 --> 0.541491).  Saving model ...
# 240 0.5502052903175354 0.8563380241394043 0.5414907932281494 0.8314606547355652 0.5880039930343628 0.8215222954750061
# Validation loss decreased (0.541491 --> 0.541243).  Saving model ...
# 241 0.5499609708786011 0.8563380241394043 0.5412433743476868 0.8314606547355652 0.5878220796585083 0.8215222954750061
# Validation loss decreased (0.541243 --> 0.540997).  Saving model ...
# 242 0.5497182607650757 0.8563380241394043 0.5409969091415405 0.8314606547355652 0.5876408815383911 0.8215222954750061
# Validation loss decreased (0.540997 --> 0.540752).  Saving model ...
# 243 0.549475908279419 0.8563380241394043 0.5407518744468689 0.8314606547355652 0.5874605178833008 0.8215222954750061
# Validation loss decreased (0.540752 --> 0.540508).  Saving model ...
# 244 0.5492355823516846 0.8577464818954468 0.5405076146125793 0.8314606547355652 0.587281346321106 0.8215222954750061
# Validation loss decreased (0.540508 --> 0.540265).  Saving model ...
# 919 0.4866476356983185 0.8788732290267944 0.47484585642814636 0.8764045238494873 0.5396619439125061 0.8451443314552307
# Validation loss decreased (0.474846 --> 0.474805).  Saving model ...
# 920 0.48660728335380554 0.8788732290267944 0.4748046100139618 0.8764045238494873 0.5396325588226318 0.8451443314552307
# Validation loss decreased (0.474805 --> 0.474764).  Saving model ...
# 921 0.4865676760673523 0.8788732290267944 0.47476357221603394 0.8764045238494873 0.5396032929420471 0.8451443314552307
# Validation loss decreased (0.474764 --> 0.474722).  Saving model ...
# 922 0.4865277409553528 0.8788732290267944 0.4747222661972046 0.8764045238494873 0.5395740866661072 0.8451443314552307
# Validation loss decreased (0.474722 --> 0.474681).  Saving model ...
# 923 0.4864879548549652 0.8788732290267944 0.47468137741088867 0.8764045238494873 0.5395447611808777 0.8451443314552307
# Validation loss decreased (0.474681 --> 0.474640).  Saving model ...
# 924 0.48644793033599854 0.8788732290267944 0.4746403396129608 0.8764045238494873 0.5395156741142273 0.8451443314552307
# Validation loss decreased (0.474640 --> 0.474600).  Saving model ...
# 925 0.48640841245651245 0.8788732290267944 0.4745995104312897 0.8764045238494873 0.5394864082336426 0.8451443314552307
# Validation loss decreased (0.474600 --> 0.474559).  Saving model ...
# 926 0.48636865615844727 0.8788732290267944 0.4745589792728424 0.8764045238494873 0.5394576787948608 0.8451443314552307
# Validation loss decreased (0.474559 --> 0.474518).  Saving model ...
# 927 0.48632901906967163 0.8788732290267944 0.47451815009117126 0.8764045238494873 0.5394283533096313 0.8451443314552307
# Validation loss decreased (0.474518 --> 0.474478).  Saving model ...
# 928 0.4862890839576721 0.8788732290267944 0.47447770833969116 0.8764045238494873 0.5393995046615601 0.8451443314552307
# Validation loss decreased (0.474478 --> 0.474437).  Saving model ...
# 929 0.4862498641014099 0.8802816867828369 0.4744369685649872 0.8764045238494873 0.5393705368041992 0.8451443314552307
# Validation loss decreased (0.474437 --> 0.474396).  Saving model ...
# 930 0.48621034622192383 0.8802816867828369 0.4743964374065399 0.8764045238494873 0.5393416285514832 0.8451443314552307
# Validation loss decreased (0.474396 --> 0.474356).  Saving model ...
# 931 0.48617079854011536 0.8802816867828369 0.474356085062027 0.8764045238494873 0.539313018321991 0.8451443314552307
# Validation loss decreased (0.474356 --> 0.474316).  Saving model ...
# 932 0.48613157868385315 0.8802816867828369 0.4743155539035797 0.8764045238494873 0.539284348487854 0.8451443314552307
# Validation loss decreased (0.474316 --> 0.474275).  Saving model ...
# 933 0.4860919117927551 0.8802816867828369 0.4742754399776459 0.8764045238494873 0.5392553806304932 0.8451443314552307
# Validation loss decreased (0.474275 --> 0.474235).  Saving model ...
# 934 0.4860527515411377 0.8802816867828369 0.4742351174354553 0.8764045238494873 0.539226770401001 0.8451443314552307
# Validation loss decreased (0.474235 --> 0.474195).  Saving model ...
# 935 0.4860134720802307 0.8802816867828369 0.4741949439048767 0.8764045238494873 0.5391976833343506 0.8451443314552307
# Validation loss decreased (0.474195 --> 0.474155).  Saving model ...
# 936 0.485973984003067 0.8802816867828369 0.4741547405719757 0.8764045238494873 0.5391692519187927 0.8451443314552307
# Validation loss decreased (0.474155 --> 0.474115).  Saving model ...
# 937 0.48593467473983765 0.8802816867828369 0.4741148352622986 0.8764045238494873 0.5391405820846558 0.8451443314552307
# Validation loss decreased (0.474115 --> 0.474075).  Saving model ...
# 938 0.48589572310447693 0.8802816867828369 0.4740748703479767 0.8764045238494873 0.5391120314598083 0.8451443314552307
# Validation loss decreased (0.474075 --> 0.474035).  Saving model ...
# 939 0.4858563542366028 0.8802816867828369 0.4740348160266876 0.8764045238494873 0.5390837788581848 0.8451443314552307
# Validation loss decreased (0.474035 --> 0.473995).  Saving model ...
# 940 0.4858172833919525 0.8802816867828369 0.47399529814720154 0.8764045238494873 0.5390551686286926 0.8451443314552307
# Validation loss decreased (0.473995 --> 0.473955).  Saving model ...
# 941 0.4857781231403351 0.8802816867828369 0.4739551544189453 0.8764045238494873 0.5390269756317139 0.8451443314552307
# Validation loss decreased (0.473955 --> 0.473916).  Saving model ...
# 942 0.4857390224933624 0.8802816867828369 0.47391563653945923 0.8764045238494873 0.538998544216156 0.8451443314552307
# Validation loss decreased (0.473916 --> 0.473876).  Saving model ...
# 943 0.4857002794742584 0.8802816867828369 0.473876029253006 0.8764045238494873 0.5389702916145325 0.8451443314552307
# Validation loss decreased (0.473876 --> 0.473836).  Saving model ...
# 944 0.48566120862960815 0.8802816867828369 0.47383642196655273 0.8764045238494873 0.5389423966407776 0.8451443314552307
# Validation loss decreased (0.473836 --> 0.473797).  Saving model ...
# 945 0.48562243580818176 0.8802816867828369 0.4737970530986786 0.8764045238494873 0.5389140248298645 0.8451443314552307
# Validation loss decreased (0.473797 --> 0.473758).  Saving model ...
# 946 0.485583633184433 0.8802816867828369 0.47375765442848206 0.8764045238494873 0.538885772228241 0.8451443314552307
# Validation loss decreased (0.473758 --> 0.473718).  Saving model ...
# 947 0.48554518818855286 0.8802816867828369 0.4737183153629303 0.8764045238494873 0.5388577580451965 0.8451443314552307
# Validation loss decreased (0.473718 --> 0.473679).  Saving model ...
# 948 0.4855059087276459 0.8802816867828369 0.4736788272857666 0.8764045238494873 0.5388298034667969 0.8451443314552307
# Validation loss decreased (0.473679 --> 0.473640).  Saving model ...
# 949 0.4854670464992523 0.8802816867828369 0.473639577627182 0.8764045238494873 0.538801908493042 0.8451443314552307
# Validation loss decreased (0.473640 --> 0.473600).  Saving model ...
# 950 0.4854283034801483 0.8802816867828369 0.47360047698020935 0.8764045238494873 0.5387741327285767 0.8451443314552307
# Validation loss decreased (0.473600 --> 0.473561).  Saving model ...
# 951 0.48539015650749207 0.8802816867828369 0.47356119751930237 0.8764045238494873 0.5387458801269531 0.8451443314552307
# Validation loss decreased (0.473561 --> 0.473522).  Saving model ...
# 952 0.48535096645355225 0.8788732290267944 0.47352245450019836 0.8764045238494873 0.5387181043624878 0.8451443314552307
# Validation loss decreased (0.473522 --> 0.473483).  Saving model ...
# 987 0.48402267694473267 0.8788732290267944 0.47219717502593994 0.882022500038147 0.5377725958824158 0.8451443314552307
# Validation loss decreased (0.472197 --> 0.472160).  Saving model ...
# 988 0.48398518562316895 0.8788732290267944 0.4721603989601135 0.882022500038147 0.5377461314201355 0.8451443314552307
# Validation loss decreased (0.472160 --> 0.472124).  Saving model ...
# 989 0.4839482307434082 0.8788732290267944 0.472123920917511 0.882022500038147 0.5377200841903687 0.8451443314552307
# Validation loss decreased (0.472124 --> 0.472087).  Saving model ...
# 990 0.483910471200943 0.8788732290267944 0.4720873236656189 0.882022500038147 0.537693977355957 0.8451443314552307
# Validation loss decreased (0.472087 --> 0.472051).  Saving model ...
# 991 0.48387354612350464 0.8788732290267944 0.4720505475997925 0.882022500038147 0.5376679301261902 0.8451443314552307
# Validation loss decreased (0.472051 --> 0.472014).  Saving model ...
# 992 0.48383641242980957 0.8788732290267944 0.4720141887664795 0.882022500038147 0.537641704082489 0.8451443314552307
# Validation loss decreased (0.472014 --> 0.471978).  Saving model ...
# 993 0.4837990701198578 0.8788732290267944 0.47197794914245605 0.882022500038147 0.5376157760620117 0.8451443314552307
# Validation loss decreased (0.471978 --> 0.471941).  Saving model ...
# 994 0.48376187682151794 0.8788732290267944 0.47194138169288635 0.882022500038147 0.537589967250824 0.8451443314552307
# Validation loss decreased (0.471941 --> 0.471905).  Saving model ...
# 995 0.4837247133255005 0.8788732290267944 0.47190526127815247 0.882022500038147 0.5375639200210571 0.8451443314552307
# Validation loss decreased (0.471905 --> 0.471869).  Saving model ...
# 996 0.48368749022483826 0.8788732290267944 0.4718691110610962 0.882022500038147 0.5375384092330933 0.8451443314552307
# Validation loss decreased (0.471869 --> 0.471833).  Saving model ...
# 997 0.4836506247520447 0.8788732290267944 0.4718329906463623 0.882022500038147 0.5375120639801025 0.8451443314552307
# Validation loss decreased (0.471833 --> 0.471797).  Saving model ...
# 998 0.4836133122444153 0.8788732290267944 0.47179698944091797 0.882022500038147 0.5374864339828491 0.8451443314552307
# Validation loss decreased (0.471797 --> 0.471761).  Saving model ...
# 999 0.4835764467716217 0.8788732290267944 0.47176089882850647 0.882022500038147 0.5374609231948853 0.8451443314552307
# <All keys matched successfully>

# %%
print(Precision(prediction, Y_train_tensor))
print(Precision(val_prediction, Y_valid_tensor))
print(Precision(test_prediction, Y_test_tensor))
# Out:
# [0.9546279311180115, 0.6163522005081177]
# [0.9772727489471436, 0.6086956262588501]
# [0.9331103563308716, 0.5243902206420898]

# %%
print(Recall(prediction, Y_train_tensor))
print(Recall(val_prediction, Y_valid_tensor))
print(Recall(test_prediction, Y_test_tensor))
# Out:
# [0.8960817456245422, 0.7967479825019836]
# [0.8775510191917419, 0.9032257795333862]
# [0.8773584961891174, 0.682539701461792]

# %%
print(Accuracy(prediction, Y_train_tensor))
print(Accuracy(val_prediction, Y_valid_tensor))
print(Accuracy(test_prediction, Y_test_tensor))
# Out:
# 0.8788732290267944
# 0.882022500038147
# 0.8451443314552307
