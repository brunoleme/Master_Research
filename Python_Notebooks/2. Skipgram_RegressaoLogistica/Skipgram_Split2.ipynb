# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import torch

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
def Accuracy(prediction, observation):
  prediction = prediction[:,1]
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  correct = (prediction_class == observation).float().sum()
  accuracy = correct/prediction_class.shape[0]
  return float(accuracy.cpu())

def Precision(prediction, observation):
  prediction = prediction[:,1]
  res = []
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  for label in [0, 1]:
    correct = (prediction_class[prediction_class == label] == observation[prediction_class == label]).float().sum()
    precision = correct/prediction_class[prediction_class == label].shape[0]
    res.append(float(precision.cpu()))
  return res

def Recall(prediction, observation):
  prediction = prediction[:,1]
  res = []
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  for label in [0, 1]:
    correct = (prediction_class[observation == label] == observation[observation == label]).float().sum()
    recall = correct/prediction_class[observation == label].shape[0]
    res.append(float(recall.cpu()))
  return res

# %%
n_split = 2

# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open('/content/drive/My Drive/Data Master/X_train_final', 'rb') as file:
    X_train = pickle.load(file)

with open('/content/drive/My Drive/Data Master/Y_train_final', 'rb') as file:
    Y_train = pickle.load(file)

with open('/content/drive/My Drive/Data Master/X_test_final', 'rb') as file:
    X_test = pickle.load(file)

with open('/content/drive/My Drive/Data Master/Y_test_final', 'rb') as file:
    Y_test = pickle.load(file)

with open('/content/drive/My Drive/Data Master/word_index_final', 'rb') as file:
    word_index = pickle.load(file)

with open('/content/drive/My Drive/Data Master/train_index_final_split_' + str(n_split), 'rb') as file:
    train_index = pickle.load(file)

with open('/content/drive/My Drive/Data Master/valid_index_final_split_' + str(n_split), 'rb') as file:
    valid_index = pickle.load(file)

# %%
inv_word_index = {ix : w for w, ix in word_index.items()}

# %%
errors = []
embeddings_index = {}
f = open('/content/drive/My Drive/Data Master/skip_s50.txt')
for line in f:
    values = line.split()
    word = values[0]
    try:
      coefs = np.asarray(values[1:], dtype='float32')
    except:
      errors.append(line)
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 929595 word vectors.

# %%
print(len(embeddings_index))
print(len(errors))
# Out:
# 929595
# 4

# %%
EMBEDDING_DIM = 50
errors_2 = []
nomatchs = []

X_train_matrix = np.zeros((len(X_train), EMBEDDING_DIM))
X_test_matrix = np.zeros((len(X_test), EMBEDDING_DIM))

# %%
for i, x in enumerate(X_train):
  for w in x:
    embedding_vector = embeddings_index.get(inv_word_index[w])
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        try:
          X_train_matrix[i] += embedding_vector
        except:
          errors_2.append([word, len(embedding_vector), embedding_vector])
    else:
      nomatchs.append(word)

# %%
for i, x in enumerate(X_test):
  for w in x:
    embedding_vector = embeddings_index.get(inv_word_index[w])
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        try:
          X_test_matrix[i] += embedding_vector
        except:
          errors_2.append([word, len(embedding_vector), embedding_vector])
    else:
      nomatchs.append(word)

# %%
X_train_matrix.shape
# Out:
# (888, 50)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
input_dim = X_train_matrix.shape[1]
input_dim
# Out:
# 50

# %%
class LogisticRegression (nn.Module):

  def __init__(self):
    super(LogisticRegression, self).__init__()

    self.fc1 = nn.Linear(input_dim, 2)
                                
    self.softmax = nn.Softmax(dim=1)

  def forward(self, x):
    x = F.normalize(x)
    y = self.softmax(self.fc1(x))

    return y

# %%
X_train_tensor = torch.from_numpy(X_train_matrix[train_index]).float()
Y_train_tensor = torch.LongTensor(np.array(Y_train[train_index]))

X_valid_tensor = torch.from_numpy(X_train_matrix[valid_index]).float()
Y_valid_tensor = torch.LongTensor(np.array(Y_train[valid_index]))

X_test_tensor = torch.from_numpy(X_test_matrix).float()
Y_test_tensor = torch.LongTensor(np.array(Y_test))

# %%
model = LogisticRegression()

# %%
torch.manual_seed(0)
np.random.seed(0)

# %%
import torch.optim as optim
optimizer = optim.AdamW(model.parameters(), lr=0.01)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
weights = [sum(Y_train)/len(Y_train), 1-sum(Y_train)/len(Y_train)]
class_weights = torch.FloatTensor(weights)
class_weights
# Out:
# tensor([0.1734, 0.8266])

# %%
criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
patience = 20
early_stopping = EarlyStopping(patience=patience, verbose=True)


for i in range(1000):
  model.train()
  optimizer.zero_grad()
  prediction = model(X_train_tensor)
  loss = criterion(prediction, Y_train_tensor)
  loss.backward()
  optimizer.step()

  accuracy = Accuracy(prediction, Y_train_tensor)

  model.eval()

  val_prediction = model(X_valid_tensor)
  test_prediction = model(X_test_tensor)
  val_loss = criterion(val_prediction, Y_valid_tensor)
  test_loss = criterion(test_prediction, Y_test_tensor)

  val_accuracy = Accuracy(val_prediction, Y_valid_tensor)
  test_accuracy = Accuracy(test_prediction, Y_test_tensor)

  early_stopping(val_loss, model)

  if early_stopping.early_stop:
    print("Early stopping")
    break

  print(i, float(loss.cpu()), accuracy, float(val_loss.cpu()), val_accuracy, float(test_loss.cpu()), test_accuracy)

  scheduler.step(val_loss)

model.load_state_dict(torch.load('checkpoint.pt'))
# Out:
# Validation loss decreased (inf --> 0.691687).  Saving model ...
# 0 0.6937927603721619 0.17323943972587585 0.6916866302490234 0.20224718749523163 0.6926920413970947 0.18372704088687897
# Validation loss decreased (0.691687 --> 0.690426).  Saving model ...
# 1 0.6922654509544373 0.1873239427804947 0.6904256343841553 0.7808988690376282 0.6913102865219116 0.8188976645469666
# Validation loss decreased (0.690426 --> 0.689273).  Saving model ...
# 2 0.6910409331321716 0.7676056623458862 0.6892731189727783 0.8370786309242249 0.6902260780334473 0.847769021987915
# Validation loss decreased (0.689273 --> 0.688102).  Saving model ...
# 3 0.689920961856842 0.8436619639396667 0.6881023645401001 0.8370786309242249 0.6892840266227722 0.847769021987915
# Validation loss decreased (0.688102 --> 0.686881).  Saving model ...
# 4 0.6887825131416321 0.8436619639396667 0.6868806481361389 0.8483145833015442 0.6884068250656128 0.8582677245140076
# Validation loss decreased (0.686881 --> 0.685627).  Saving model ...
# 5 0.6875946521759033 0.8535211086273193 0.6856269240379333 0.882022500038147 0.6875730156898499 0.8713910579681396
# Validation loss decreased (0.685627 --> 0.684372).  Saving model ...
# 6 0.6863764524459839 0.8633802533149719 0.6843715906143188 0.8651685118675232 0.6867773532867432 0.8635170459747314
# Validation loss decreased (0.684372 --> 0.683135).  Saving model ...
# 7 0.6851568818092346 0.8535211086273193 0.6831353902816772 0.7921348214149475 0.6860126256942749 0.7952755689620972
# Validation loss decreased (0.663303 --> 0.662198).  Saving model ...
# 25 0.6644913554191589 0.7774648070335388 0.6621978282928467 0.7584269642829895 0.6711173057556152 0.7349081635475159
# Validation loss decreased (0.662198 --> 0.661100).  Saving model ...
# 26 0.6634023785591125 0.7704225182533264 0.6611001491546631 0.7584269642829895 0.6703410148620605 0.7349081635475159
# Validation loss decreased (0.661100 --> 0.660009).  Saving model ...
# 27 0.6623188853263855 0.7704225182533264 0.6600094437599182 0.7584269642829895 0.6695546507835388 0.7349081635475159
# Validation loss decreased (0.660009 --> 0.658928).  Saving model ...
# 28 0.6612399816513062 0.7788732647895813 0.6589275002479553 0.7696629166603088 0.6687639951705933 0.7454068064689636
# Validation loss decreased (0.658928 --> 0.657856).  Saving model ...
# 29 0.6601681113243103 0.7859154939651489 0.6578555107116699 0.7752808928489685 0.6679758429527283 0.7506561875343323
# Validation loss decreased (0.657856 --> 0.656794).  Saving model ...
# 30 0.6591050624847412 0.794366180896759 0.6567935943603516 0.7752808928489685 0.66719651222229 0.7559055089950562
# Validation loss decreased (0.656794 --> 0.655741).  Saving model ...
# 31 0.6580514907836914 0.8014084696769714 0.6557405591011047 0.7808988690376282 0.6664316654205322 0.7664042115211487
# Validation loss decreased (0.655741 --> 0.654695).  Saving model ...
# 32 0.6570064425468445 0.8056337833404541 0.654694676399231 0.7921348214149475 0.665682852268219 0.7769029140472412
# Validation loss decreased (0.654695 --> 0.653655).  Saving model ...
# 33 0.6559689044952393 0.8056337833404541 0.6536547541618347 0.7921348214149475 0.6649512052536011 0.7769029140472412
# Validation loss decreased (0.653655 --> 0.652621).  Saving model ...
# 34 0.6549391150474548 0.8070422410964966 0.6526213884353638 0.7865168452262878 0.6642345190048218 0.7664042115211487
# Validation loss decreased (0.652621 --> 0.651595).  Saving model ...
# 35 0.6539161205291748 0.8070422410964966 0.6515951156616211 0.7808988690376282 0.6635317206382751 0.7585301995277405
# Validation loss decreased (0.651595 --> 0.650578).  Saving model ...
# 36 0.6528999209403992 0.8014084696769714 0.6505779027938843 0.7752808928489685 0.6628390550613403 0.7585301995277405
# Validation loss decreased (0.650578 --> 0.649570).  Saving model ...
# 37 0.6518930196762085 0.7985915541648865 0.6495702862739563 0.7752808928489685 0.6621529459953308 0.7506561875343323
# Validation loss decreased (0.649570 --> 0.648572).  Saving model ...
# 38 0.6508950591087341 0.794366180896759 0.6485723257064819 0.7752808928489685 0.6614671945571899 0.7532808184623718
# Validation loss decreased (0.648572 --> 0.647583).  Saving model ...
# 39 0.6499055624008179 0.7929577231407166 0.6475833654403687 0.7696629166603088 0.6607809662818909 0.7532808184623718
# Validation loss decreased (0.647583 --> 0.646603).  Saving model ...
# 40 0.6489239931106567 0.7915493249893188 0.6466033458709717 0.7752808928489685 0.6600918769836426 0.7506561875343323
# Validation loss decreased (0.646603 --> 0.645632).  Saving model ...
# 41 0.6479495167732239 0.794366180896759 0.6456324458122253 0.7752808928489685 0.6594029664993286 0.7559055089950562
# Validation loss decreased (0.630410 --> 0.629587).  Saving model ...
# 59 0.631779134273529 0.8028169274330139 0.6295869946479797 0.7977527976036072 0.6481828093528748 0.76115483045578
# Validation loss decreased (0.629587 --> 0.628771).  Saving model ...
# 60 0.6309543251991272 0.8028169274330139 0.6287710666656494 0.7977527976036072 0.6476197838783264 0.76115483045578
# Validation loss decreased (0.628771 --> 0.627963).  Saving model ...
# 61 0.6301363706588745 0.8028169274330139 0.6279630661010742 0.7977527976036072 0.6470620632171631 0.76115483045578
# Validation loss decreased (0.627963 --> 0.627163).  Saving model ...
# 62 0.629326343536377 0.8028169274330139 0.6271630525588989 0.7977527976036072 0.6465082168579102 0.76115483045578
# Validation loss decreased (0.627163 --> 0.626370).  Saving model ...
# 63 0.628523051738739 0.8028169274330139 0.626370370388031 0.7977527976036072 0.6459564566612244 0.76115483045578
# Validation loss decreased (0.626370 --> 0.625586).  Saving model ...
# 64 0.6277267336845398 0.8056337833404541 0.625585675239563 0.7977527976036072 0.6454071998596191 0.76115483045578
# Validation loss decreased (0.625586 --> 0.624809).  Saving model ...
# 65 0.6269374489784241 0.8070422410964966 0.6248087882995605 0.7977527976036072 0.6448601484298706 0.76115483045578
# Validation loss decreased (0.624809 --> 0.624039).  Saving model ...
# 66 0.6261554956436157 0.8084506988525391 0.6240391135215759 0.7977527976036072 0.6443163752555847 0.7637795209884644
# Validation loss decreased (0.624039 --> 0.623277).  Saving model ...
# 67 0.625380277633667 0.8084506988525391 0.623276948928833 0.7977527976036072 0.6437779068946838 0.7637795209884644
# Validation loss decreased (0.623277 --> 0.622521).  Saving model ...
# 68 0.6246121525764465 0.8084506988525391 0.622521162033081 0.7977527976036072 0.6432448029518127 0.7637795209884644
# Validation loss decreased (0.622521 --> 0.621773).  Saving model ...
# 69 0.6238508224487305 0.8084506988525391 0.6217725872993469 0.7977527976036072 0.6427183151245117 0.7637795209884644
# Validation loss decreased (0.621773 --> 0.621030).  Saving model ...
# 70 0.6230956315994263 0.8084506988525391 0.6210302710533142 0.7977527976036072 0.6421988010406494 0.7637795209884644
# Validation loss decreased (0.621030 --> 0.620295).  Saving model ...
# 71 0.6223475337028503 0.8098591566085815 0.620294988155365 0.7977527976036072 0.6416850090026855 0.7637795209884644
# Validation loss decreased (0.620295 --> 0.619567).  Saving model ...
# 72 0.6216056942939758 0.8098591566085815 0.6195665597915649 0.7977527976036072 0.6411764025688171 0.7637795209884644
# Validation loss decreased (0.619567 --> 0.618845).  Saving model ...
# 73 0.6208710670471191 0.8098591566085815 0.6188446283340454 0.7977527976036072 0.6406713724136353 0.7637795209884644
# Validation loss decreased (0.618845 --> 0.618130).  Saving model ...
# 74 0.6201423406600952 0.8084506988525391 0.6181296110153198 0.7977527976036072 0.6401693820953369 0.7637795209884644
# Validation loss decreased (0.618130 --> 0.617421).  Saving model ...
# 75 0.6194202303886414 0.8084506988525391 0.6174213886260986 0.7977527976036072 0.6396695971488953 0.7637795209884644
# Validation loss decreased (0.617421 --> 0.616720).  Saving model ...
# 76 0.6187041997909546 0.8084506988525391 0.6167195439338684 0.7977527976036072 0.6391724944114685 0.7637795209884644
# Validation loss decreased (0.616720 --> 0.616025).  Saving model ...
# 77 0.6179940700531006 0.8098591566085815 0.6160246133804321 0.7977527976036072 0.638678789138794 0.7637795209884644
# Validation loss decreased (0.616025 --> 0.615336).  Saving model ...
# 78 0.617290198802948 0.8098591566085815 0.6153357625007629 0.7977527976036072 0.6381887197494507 0.7664042115211487
# Validation loss decreased (0.615336 --> 0.614653).  Saving model ...
# 79 0.6165925860404968 0.8098591566085815 0.614653468132019 0.7977527976036072 0.6377028822898865 0.7690288424491882
# Validation loss decreased (0.614653 --> 0.613977).  Saving model ...
# 80 0.6159008741378784 0.8098591566085815 0.6139766573905945 0.7977527976036072 0.6372226476669312 0.7690288424491882
# Validation loss decreased (0.613977 --> 0.613306).  Saving model ...
# 81 0.6152150630950928 0.8098591566085815 0.6133059859275818 0.7977527976036072 0.6367473602294922 0.7690288424491882
# Validation loss decreased (0.613306 --> 0.612641).  Saving model ...
# 82 0.6145353317260742 0.8098591566085815 0.6126412749290466 0.7977527976036072 0.6362767815589905 0.7690288424491882
# Validation loss decreased (0.612641 --> 0.611982).  Saving model ...
# 83 0.6138607859611511 0.8084506988525391 0.6119820475578308 0.7977527976036072 0.6358102560043335 0.7690288424491882
# Validation loss decreased (0.611982 --> 0.611329).  Saving model ...
# 84 0.6131927371025085 0.8084506988525391 0.6113292574882507 0.7977527976036072 0.6353473663330078 0.7690288424491882
# Validation loss decreased (0.611329 --> 0.610682).  Saving model ...
# 85 0.6125296950340271 0.8084506988525391 0.6106821298599243 0.7977527976036072 0.6348869204521179 0.7690288424491882
# Validation loss decreased (0.610682 --> 0.610041).  Saving model ...
# 86 0.6118720769882202 0.8098591566085815 0.6100408434867859 0.7977527976036072 0.6344289779663086 0.7716535329818726
# Validation loss decreased (0.610041 --> 0.609405).  Saving model ...
# 87 0.6112202405929565 0.811267614364624 0.6094053387641907 0.7977527976036072 0.6339731812477112 0.7742782235145569
# Validation loss decreased (0.609405 --> 0.608775).  Saving model ...
# 88 0.610573947429657 0.811267614364624 0.60877525806427 0.7977527976036072 0.6335210204124451 0.7742782235145569
# Validation loss decreased (0.608775 --> 0.608151).  Saving model ...
# 89 0.6099324822425842 0.811267614364624 0.6081507802009583 0.7977527976036072 0.6330724358558655 0.7742782235145569
# Validation loss decreased (0.608151 --> 0.607532).  Saving model ...
# 90 0.6092966794967651 0.811267614364624 0.6075319051742554 0.7977527976036072 0.632627010345459 0.7795275449752808
# Validation loss decreased (0.607532 --> 0.606918).  Saving model ...
# 91 0.6086663603782654 0.811267614364624 0.6069179177284241 0.7977527976036072 0.6321861147880554 0.7795275449752808
# Validation loss decreased (0.606918 --> 0.606309).  Saving model ...
# 92 0.6080408692359924 0.811267614364624 0.6063089370727539 0.7977527976036072 0.6317493915557861 0.7795275449752808
# Validation loss decreased (0.606309 --> 0.605706).  Saving model ...
# 93 0.6074209809303284 0.811267614364624 0.605705738067627 0.7977527976036072 0.6313160061836243 0.7821522355079651
# Validation loss decreased (0.605706 --> 0.605107).  Saving model ...
# 94 0.6068052053451538 0.811267614364624 0.6051074266433716 0.7921348214149475 0.630886435508728 0.7821522355079651
# Validation loss decreased (0.605107 --> 0.604514).  Saving model ...
# 95 0.6061950922012329 0.811267614364624 0.6045141816139221 0.7921348214149475 0.6304594874382019 0.7821522355079651
# Validation loss decreased (0.604514 --> 0.603926).  Saving model ...
# 96 0.605589747428894 0.811267614364624 0.6039258241653442 0.7921348214149475 0.6300342679023743 0.7847769260406494
# Validation loss decreased (0.603926 --> 0.603343).  Saving model ...
# 97 0.604989230632782 0.8126760721206665 0.603342592716217 0.7921348214149475 0.629612147808075 0.7847769260406494
# Validation loss decreased (0.603343 --> 0.602764).  Saving model ...
# 98 0.6043933033943176 0.8126760721206665 0.6027643084526062 0.7921348214149475 0.6291926503181458 0.7847769260406494
# Validation loss decreased (0.602764 --> 0.602191).  Saving model ...
# 99 0.6038020253181458 0.811267614364624 0.6021907329559326 0.7921348214149475 0.6287757754325867 0.787401556968689
# Validation loss decreased (0.602191 --> 0.601622).  Saving model ...
# 100 0.603215217590332 0.8126760721206665 0.6016222238540649 0.7921348214149475 0.6283618211746216 0.7900262475013733
# Validation loss decreased (0.601622 --> 0.601058).  Saving model ...
# 101 0.6026334762573242 0.8126760721206665 0.6010581254959106 0.7921348214149475 0.627951443195343 0.7900262475013733
# Validation loss decreased (0.601058 --> 0.600499).  Saving model ...
# 102 0.6020562052726746 0.814084529876709 0.600498616695404 0.7921348214149475 0.6275444030761719 0.7900262475013733
# Validation loss decreased (0.600499 --> 0.599944).  Saving model ...
# 103 0.6014835238456726 0.8154929280281067 0.5999435782432556 0.7921348214149475 0.627140998840332 0.7900262475013733
# Validation loss decreased (0.599944 --> 0.599393).  Saving model ...
# 104 0.6009153723716736 0.8169013857841492 0.5993930101394653 0.7921348214149475 0.6267402768135071 0.7900262475013733
# Validation loss decreased (0.599393 --> 0.598847).  Saving model ...
# 105 0.6003511548042297 0.8169013857841492 0.5988466143608093 0.7977527976036072 0.6263419389724731 0.787401556968689
# Validation loss decreased (0.598847 --> 0.598305).  Saving model ...
# 106 0.5997920036315918 0.8169013857841492 0.5983049869537354 0.7977527976036072 0.6259463429450989 0.787401556968689
# Validation loss decreased (0.598305 --> 0.597768).  Saving model ...
# 107 0.5992361307144165 0.8169013857841492 0.59776771068573 0.7977527976036072 0.6255531311035156 0.787401556968689
# Validation loss decreased (0.597768 --> 0.597235).  Saving model ...
# 108 0.5986849069595337 0.8183098435401917 0.5972346663475037 0.7977527976036072 0.6251616477966309 0.787401556968689
# Validation loss decreased (0.597235 --> 0.596706).  Saving model ...
# 109 0.5981377959251404 0.8183098435401917 0.5967057943344116 0.8033707737922668 0.6247730255126953 0.787401556968689
# Validation loss decreased (0.596706 --> 0.596181).  Saving model ...
# 178 0.5681669116020203 0.8394365906715393 0.5679385662078857 0.8539325594902039 0.6030768752098083 0.8057742714881897
# Validation loss decreased (0.567939 --> 0.567607).  Saving model ...
# 179 0.5678198337554932 0.8394365906715393 0.5676074624061584 0.8539325594902039 0.6028215289115906 0.8057742714881897
# Validation loss decreased (0.567607 --> 0.567278).  Saving model ...
# 180 0.5674752593040466 0.8394365906715393 0.5672781467437744 0.8539325594902039 0.602567732334137 0.8057742714881897
# Validation loss decreased (0.567278 --> 0.566951).  Saving model ...
# 181 0.5671322345733643 0.8408450484275818 0.5669506788253784 0.8595505356788635 0.6023150086402893 0.8057742714881897
# Validation loss decreased (0.566951 --> 0.566625).  Saving model ...
# 182 0.5667911767959595 0.8408450484275818 0.56662517786026 0.8595505356788635 0.6020639538764954 0.8057742714881897
# Validation loss decreased (0.566625 --> 0.566301).  Saving model ...
# 183 0.5664519667625427 0.8408450484275818 0.5663014650344849 0.8595505356788635 0.6018142104148865 0.808398962020874
# Validation loss decreased (0.566301 --> 0.565980).  Saving model ...
# 184 0.5661147832870483 0.8408450484275818 0.5659798979759216 0.8595505356788635 0.6015656590461731 0.808398962020874
# Validation loss decreased (0.565980 --> 0.565660).  Saving model ...
# 185 0.5657793879508972 0.8422535061836243 0.5656596422195435 0.8595505356788635 0.601318359375 0.808398962020874
# Validation loss decreased (0.565660 --> 0.565341).  Saving model ...
# 186 0.5654463768005371 0.8422535061836243 0.5653412938117981 0.8595505356788635 0.6010726094245911 0.808398962020874
# Validation loss decreased (0.565341 --> 0.565025).  Saving model ...
# 187 0.5651140809059143 0.8422535061836243 0.5650250911712646 0.8595505356788635 0.6008278131484985 0.808398962020874
# Validation loss decreased (0.565025 --> 0.564710).  Saving model ...
# 188 0.5647841691970825 0.8422535061836243 0.5647101402282715 0.8595505356788635 0.6005845069885254 0.808398962020874
# Validation loss decreased (0.564710 --> 0.564397).  Saving model ...
# 189 0.5644566416740417 0.8422535061836243 0.5643974542617798 0.8595505356788635 0.6003423929214478 0.808398962020874
# Validation loss decreased (0.564397 --> 0.564086).  Saving model ...
# 190 0.5641303658485413 0.8422535061836243 0.5640864372253418 0.8595505356788635 0.6001012325286865 0.808398962020874
# Validation loss decreased (0.564086 --> 0.563777).  Saving model ...
# 191 0.5638059377670288 0.8422535061836243 0.5637768507003784 0.8595505356788635 0.5998619794845581 0.808398962020874
# Validation loss decreased (0.563777 --> 0.563469).  Saving model ...
# 192 0.5634831786155701 0.8422535061836243 0.5634692311286926 0.8595505356788635 0.5996236205101013 0.808398962020874
# Validation loss decreased (0.563469 --> 0.563163).  Saving model ...
# 193 0.5631623268127441 0.8436619639396667 0.5631633400917053 0.8595505356788635 0.5993866920471191 0.808398962020874
# Validation loss decreased (0.563163 --> 0.562859).  Saving model ...
# 194 0.562843382358551 0.8436619639396667 0.5628589391708374 0.8595505356788635 0.5991508364677429 0.808398962020874
# Validation loss decreased (0.562859 --> 0.562556).  Saving model ...
# 195 0.5625259876251221 0.8436619639396667 0.562556266784668 0.8595505356788635 0.598916232585907 0.808398962020874
# Validation loss decreased (0.562556 --> 0.562255).  Saving model ...
# 196 0.5622100234031677 0.8436619639396667 0.5622554421424866 0.8595505356788635 0.5986826419830322 0.808398962020874
# Validation loss decreased (0.562255 --> 0.561956).  Saving model ...
# 197 0.561896026134491 0.8436619639396667 0.5619560480117798 0.8595505356788635 0.5984506011009216 0.8110235929489136
# Validation loss decreased (0.561956 --> 0.561658).  Saving model ...
# 198 0.5615835189819336 0.8436619639396667 0.5616583228111267 0.8595505356788635 0.5982195138931274 0.8110235929489136
# Validation loss decreased (0.561658 --> 0.561362).  Saving model ...
# 199 0.5612725615501404 0.8450704216957092 0.5613622069358826 0.8595505356788635 0.5979900360107422 0.8110235929489136
# Validation loss decreased (0.561362 --> 0.561068).  Saving model ...
# 200 0.5609633922576904 0.8450704216957092 0.5610676407814026 0.8595505356788635 0.5977611541748047 0.8110235929489136
# Validation loss decreased (0.561068 --> 0.560775).  Saving model ...
# 201 0.5606558918952942 0.8450704216957092 0.5607747435569763 0.8595505356788635 0.5975337028503418 0.8110235929489136
# Validation loss decreased (0.560775 --> 0.560484).  Saving model ...
# 202 0.5603500604629517 0.8450704216957092 0.5604835152626038 0.8595505356788635 0.5973072052001953 0.8136482834815979
# Validation loss decreased (0.560484 --> 0.560194).  Saving model ...
# 203 0.5600457787513733 0.8450704216957092 0.5601938366889954 0.8595505356788635 0.597082257270813 0.8136482834815979
# Validation loss decreased (0.560194 --> 0.559906).  Saving model ...
# 204 0.559743344783783 0.8450704216957092 0.5599057078361511 0.8595505356788635 0.5968582034111023 0.8136482834815979
# Validation loss decreased (0.559906 --> 0.559619).  Saving model ...
# 205 0.5594423413276672 0.8450704216957092 0.5596188902854919 0.8539325594902039 0.5966353416442871 0.8136482834815979
# Validation loss decreased (0.559619 --> 0.559334).  Saving model ...
# 206 0.5591427683830261 0.8450704216957092 0.5593339204788208 0.8539325594902039 0.5964135527610779 0.8136482834815979
# Validation loss decreased (0.559334 --> 0.559051).  Saving model ...
# 207 0.5588448643684387 0.8450704216957092 0.5590505003929138 0.8539325594902039 0.5961926579475403 0.8136482834815979
# Validation loss decreased (0.559051 --> 0.558768).  Saving model ...
# 208 0.5585483312606812 0.8464788794517517 0.5587683320045471 0.8539325594902039 0.5959733128547668 0.8136482834815979
# Validation loss decreased (0.558768 --> 0.558488).  Saving model ...
# 209 0.5582532286643982 0.8478873372077942 0.5584876537322998 0.8539325594902039 0.5957551598548889 0.8136482834815979
# Validation loss decreased (0.558488 --> 0.558209).  Saving model ...
# 210 0.5579600930213928 0.8478873372077942 0.5582085847854614 0.8539325594902039 0.5955374240875244 0.8136482834815979
# Validation loss decreased (0.558209 --> 0.557931).  Saving model ...
# 211 0.5576682090759277 0.8478873372077942 0.5579310059547424 0.8539325594902039 0.5953212380409241 0.8162729740142822
# Validation loss decreased (0.557931 --> 0.557655).  Saving model ...
# 246 0.5483168363571167 0.8535211086273193 0.5490647554397583 0.8539325594902039 0.5883790254592896 0.808398962020874
# Validation loss decreased (0.549065 --> 0.548834).  Saving model ...
# 247 0.548072099685669 0.8535211086273193 0.5488337874412537 0.8539325594902039 0.5881971716880798 0.8110235929489136
# Validation loss decreased (0.548834 --> 0.548604).  Saving model ...
# 248 0.5478289723396301 0.8535211086273193 0.5486037135124207 0.8539325594902039 0.5880160927772522 0.8110235929489136
# Validation loss decreased (0.548604 --> 0.548375).  Saving model ...
# 249 0.5475859045982361 0.8535211086273193 0.5483748912811279 0.8539325594902039 0.5878356695175171 0.8110235929489136
# Validation loss decreased (0.548375 --> 0.548147).  Saving model ...
# 250 0.5473446249961853 0.8535211086273193 0.5481472015380859 0.8539325594902039 0.5876567959785461 0.8110235929489136
# Validation loss decreased (0.548147 --> 0.547921).  Saving model ...
# 251 0.5471051335334778 0.8535211086273193 0.5479207038879395 0.8539325594902039 0.5874776840209961 0.8110235929489136
# Validation loss decreased (0.547921 --> 0.547695).  Saving model ...
# 252 0.5468654036521912 0.8535211086273193 0.5476953387260437 0.8539325594902039 0.5873002409934998 0.8110235929489136
# Validation loss decreased (0.547695 --> 0.547471).  Saving model ...
# 253 0.5466277003288269 0.8535211086273193 0.5474708080291748 0.8539325594902039 0.5871230959892273 0.8110235929489136
# Validation loss decreased (0.547471 --> 0.547247).  Saving model ...
# 254 0.5463907122612 0.8535211086273193 0.5472474694252014 0.8539325594902039 0.5869472026824951 0.8110235929489136
# Validation loss decreased (0.547247 --> 0.547026).  Saving model ...
# 255 0.5461552143096924 0.8535211086273193 0.5470255017280579 0.8539325594902039 0.586771547794342 0.8110235929489136
# Validation loss decreased (0.547026 --> 0.546804).  Saving model ...
# 256 0.5459203720092773 0.8535211086273193 0.5468044281005859 0.8539325594902039 0.586597204208374 0.8110235929489136
# Validation loss decreased (0.546804 --> 0.546584).  Saving model ...
# 257 0.545686662197113 0.8535211086273193 0.5465840101242065 0.8539325594902039 0.5864236354827881 0.8110235929489136
# Validation loss decreased (0.546584 --> 0.546365).  Saving model ...
# ...
# Validation loss decreased (0.493702 --> 0.493674).  Saving model ...
# 915 0.4824574291706085 0.8802816867828369 0.49367406964302063 0.8707864880561829 0.5396418571472168 0.8530183434486389
# Validation loss decreased (0.493674 --> 0.493646).  Saving model ...
# 916 0.4824141263961792 0.8802816867828369 0.49364638328552246 0.8707864880561829 0.5396096110343933 0.8530183434486389
# Validation loss decreased (0.493646 --> 0.493619).  Saving model ...
# 917 0.4823701083660126 0.8816901445388794 0.4936187267303467 0.8707864880561829 0.5395774245262146 0.8530183434486389
# Validation loss decreased (0.493619 --> 0.493591).  Saving model ...
# 918 0.4823264181613922 0.8816901445388794 0.49359145760536194 0.8707864880561829 0.5395458936691284 0.8530183434486389
# Validation loss decreased (0.493591 --> 0.493564).  Saving model ...
# 919 0.4822825491428375 0.8816901445388794 0.49356386065483093 0.8707864880561829 0.5395141243934631 0.8530183434486389
# Validation loss decreased (0.493564 --> 0.493537).  Saving model ...
# 920 0.48223888874053955 0.8816901445388794 0.4935365319252014 0.8707864880561829 0.5394821166992188 0.8530183434486389
# Validation loss decreased (0.493537 --> 0.493509).  Saving model ...
# 921 0.4821949601173401 0.8816901445388794 0.4935091435909271 0.8707864880561829 0.5394505858421326 0.8530183434486389
# Validation loss decreased (0.493509 --> 0.493482).  Saving model ...
# 922 0.48215141892433167 0.8816901445388794 0.49348196387290955 0.8707864880561829 0.5394186973571777 0.8530183434486389
# Validation loss decreased (0.493482 --> 0.493455).  Saving model ...
# 923 0.4821082353591919 0.8816901445388794 0.4934547245502472 0.8707864880561829 0.5393869280815125 0.8530183434486389
# Validation loss decreased (0.493455 --> 0.493428).  Saving model ...
# 924 0.4820641577243805 0.8816901445388794 0.4934275150299072 0.8707864880561829 0.5393553972244263 0.8530183434486389
# Validation loss decreased (0.493428 --> 0.493401).  Saving model ...
# 925 0.48202115297317505 0.8816901445388794 0.4934006333351135 0.8707864880561829 0.5393238663673401 0.8530183434486389
# Validation loss decreased (0.493401 --> 0.493373).  Saving model ...
# 926 0.48197752237319946 0.8816901445388794 0.49337345361709595 0.8707864880561829 0.5392924547195435 0.8530183434486389
# Validation loss decreased (0.493373 --> 0.493347).  Saving model ...
# 927 0.4819343388080597 0.8816901445388794 0.49334654211997986 0.8707864880561829 0.5392606854438782 0.8530183434486389
# Validation loss decreased (0.493347 --> 0.493320).  Saving model ...
# 928 0.48189061880111694 0.8816901445388794 0.4933197796344757 0.8707864880561829 0.5392292141914368 0.8530183434486389
# Validation loss decreased (0.493320 --> 0.493293).  Saving model ...
# 929 0.4818478226661682 0.8816901445388794 0.4932926893234253 0.8707864880561829 0.5391980409622192 0.8530183434486389
# Validation loss decreased (0.493293 --> 0.493266).  Saving model ...
# 930 0.48180463910102844 0.8816901445388794 0.49326595664024353 0.8707864880561829 0.5391669869422913 0.8530183434486389
# Validation loss decreased (0.493266 --> 0.493239).  Saving model ...
# 931 0.48176145553588867 0.8830986022949219 0.49323904514312744 0.8707864880561829 0.5391351580619812 0.8530183434486389
# Validation loss decreased (0.493239 --> 0.493213).  Saving model ...
# 932 0.4817182421684265 0.8830986022949219 0.4932125210762024 0.8707864880561829 0.5391043424606323 0.8530183434486389
# Validation loss decreased (0.493213 --> 0.493186).  Saving model ...
# 933 0.48167529702186584 0.8830986022949219 0.4931858479976654 0.8707864880561829 0.5390730500221252 0.8530183434486389
# Validation loss decreased (0.493186 --> 0.493159).  Saving model ...
# 934 0.48163190484046936 0.8830986022949219 0.4931590259075165 0.8707864880561829 0.5390418767929077 0.8530183434486389
# Validation loss decreased (0.493159 --> 0.493133).  Saving model ...
# 935 0.4815897047519684 0.8830986022949219 0.4931328296661377 0.8707864880561829 0.5390108823776245 0.8530183434486389
# Validation loss decreased (0.493133 --> 0.493106).  Saving model ...
# 936 0.48154643177986145 0.8830986022949219 0.49310603737831116 0.8707864880561829 0.5389797687530518 0.8530183434486389
# Validation loss decreased (0.493106 --> 0.493080).  Saving model ...
# 937 0.4815034866333008 0.8830986022949219 0.49307987093925476 0.8707864880561829 0.5389488935470581 0.8530183434486389
# Validation loss decreased (0.493080 --> 0.493053).  Saving model ...
# 938 0.4814610183238983 0.8830986022949219 0.49305322766304016 0.8707864880561829 0.5389177203178406 0.8530183434486389
# Validation loss decreased (0.493053 --> 0.493027).  Saving model ...
# 939 0.48141834139823914 0.8830986022949219 0.4930269718170166 0.8707864880561829 0.5388871431350708 0.8530183434486389
# Validation loss decreased (0.493027 --> 0.493001).  Saving model ...
# 940 0.4813757836818695 0.8830986022949219 0.4930008351802826 0.8707864880561829 0.5388560891151428 0.8530183434486389
# Validation loss decreased (0.493001 --> 0.492975).  Saving model ...
# 941 0.4813331961631775 0.8830986022949219 0.4929746985435486 0.8707864880561829 0.5388250946998596 0.8530183434486389
# Validation loss decreased (0.492975 --> 0.492948).  Saving model ...
# 942 0.4812903106212616 0.8830986022949219 0.49294841289520264 0.8707864880561829 0.5387943387031555 0.8530183434486389
# Validation loss decreased (0.492948 --> 0.492922).  Saving model ...
# 943 0.4812479317188263 0.8830986022949219 0.49292245507240295 0.8707864880561829 0.538763701915741 0.8530183434486389
# Validation loss decreased (0.492922 --> 0.492896).  Saving model ...
# 944 0.4812052249908447 0.8830986022949219 0.49289625883102417 0.8707864880561829 0.538733184337616 0.8530183434486389
# Validation loss decreased (0.492896 --> 0.492870).  Saving model ...
# 945 0.4811631143093109 0.8830986022949219 0.4928703010082245 0.8707864880561829 0.5387023687362671 0.8530183434486389
# Validation loss decreased (0.492870 --> 0.492844).  Saving model ...
# 946 0.4811204671859741 0.8830986022949219 0.4928444027900696 0.8707864880561829 0.5386720299720764 0.8530183434486389
# Validation loss decreased (0.492844 --> 0.492819).  Saving model ...
# 947 0.4810783565044403 0.8830986022949219 0.4928186237812042 0.8707864880561829 0.5386415719985962 0.8530183434486389
# Validation loss decreased (0.492819 --> 0.492793).  Saving model ...
# 948 0.48103636503219604 0.8830986022949219 0.49279260635375977 0.8707864880561829 0.538611114025116 0.8530183434486389
# Validation loss decreased (0.492793 --> 0.492767).  Saving model ...
# 949 0.48099392652511597 0.8830986022949219 0.4927668571472168 0.8707864880561829 0.5385807752609253 0.8530183434486389
# Validation loss decreased (0.492767 --> 0.492741).  Saving model ...
# 950 0.4809519946575165 0.8830986022949219 0.49274128675460815 0.8707864880561829 0.5385499596595764 0.8530183434486389
# Validation loss decreased (0.492741 --> 0.492716).  Saving model ...
# 951 0.4809092581272125 0.8830986022949219 0.4927155375480652 0.8707864880561829 0.5385198593139648 0.8530183434486389
# Validation loss decreased (0.492716 --> 0.492690).  Saving model ...
# 952 0.48086783289909363 0.8830986022949219 0.49268975853919983 0.8707864880561829 0.5384894013404846 0.8530183434486389
# Validation loss decreased (0.492690 --> 0.492664).  Saving model ...
# 953 0.4808255732059479 0.8830986022949219 0.49266430735588074 0.8707864880561829 0.538459300994873 0.8530183434486389
# Validation loss decreased (0.492664 --> 0.492639).  Saving model ...
# 954 0.4807838201522827 0.8830986022949219 0.49263882637023926 0.8707864880561829 0.5384290218353271 0.8530183434486389
# Validation loss decreased (0.492639 --> 0.492613).  Saving model ...
# 955 0.4807422161102295 0.8830986022949219 0.4926133453845978 0.8707864880561829 0.5383988618850708 0.8530183434486389
# Validation loss decreased (0.492613 --> 0.492588).  Saving model ...
# 956 0.48069992661476135 0.8830986022949219 0.4925878942012787 0.8707864880561829 0.5383689403533936 0.8530183434486389
# Validation loss decreased (0.492588 --> 0.492563).  Saving model ...
# 957 0.48065853118896484 0.8830986022949219 0.49256256222724915 0.8707864880561829 0.5383387804031372 0.8530183434486389
# Validation loss decreased (0.492563 --> 0.492537).  Saving model ...
# 958 0.4806164503097534 0.8830986022949219 0.49253734946250916 0.8707864880561829 0.53830885887146 0.8530183434486389
# Validation loss decreased (0.492537 --> 0.492512).  Saving model ...
# 959 0.480574369430542 0.8830986022949219 0.4925118684768677 0.8707864880561829 0.5382789969444275 0.8530183434486389
# Validation loss decreased (0.492512 --> 0.492487).  Saving model ...
# 960 0.4805329740047455 0.8830986022949219 0.49248674511909485 0.8707864880561829 0.5382488369941711 0.8530183434486389
# Validation loss decreased (0.492487 --> 0.492462).  Saving model ...
# 961 0.48049136996269226 0.8830986022949219 0.49246159195899963 0.8707864880561829 0.5382188558578491 0.8530183434486389
# Validation loss decreased (0.492462 --> 0.492436).  Saving model ...
# 962 0.48044973611831665 0.8830986022949219 0.4924364984035492 0.8707864880561829 0.5381891131401062 0.8530183434486389
# Validation loss decreased (0.492436 --> 0.492411).  Saving model ...
# 963 0.4804081618785858 0.8830986022949219 0.49241137504577637 0.8707864880561829 0.5381594896316528 0.8530183434486389
# Validation loss decreased (0.492411 --> 0.492386).  Saving model ...
# 964 0.4803667962551117 0.8830986022949219 0.4923864006996155 0.8707864880561829 0.5381296873092651 0.8530183434486389
# Validation loss decreased (0.492386 --> 0.492361).  Saving model ...
# 965 0.4803254008293152 0.8830986022949219 0.49236148595809937 0.8707864880561829 0.538100004196167 0.8530183434486389
# Validation loss decreased (0.492361 --> 0.492337).  Saving model ...
# 966 0.4802837669849396 0.8830986022949219 0.49233657121658325 0.8707864880561829 0.5380702614784241 0.8530183434486389
# Validation loss decreased (0.492337 --> 0.492312).  Saving model ...
# 967 0.4802427589893341 0.8830986022949219 0.4923117458820343 0.8707864880561829 0.5380403399467468 0.8530183434486389
# Validation loss decreased (0.492312 --> 0.492287).  Saving model ...
# 968 0.48020127415657043 0.8830986022949219 0.4922867715358734 0.8707864880561829 0.5380111336708069 0.8530183434486389
# Validation loss decreased (0.492287 --> 0.492262).  Saving model ...
# 969 0.4801601767539978 0.8830986022949219 0.4922621250152588 0.8707864880561829 0.5379816889762878 0.8530183434486389
# Validation loss decreased (0.492262 --> 0.492238).  Saving model ...
# 970 0.48011907935142517 0.8830986022949219 0.49223753809928894 0.8707864880561829 0.537952184677124 0.8530183434486389
# Validation loss decreased (0.492238 --> 0.492213).  Saving model ...
# 971 0.48007798194885254 0.8830986022949219 0.4922126829624176 0.8707864880561829 0.5379226803779602 0.8530183434486389
# Validation loss decreased (0.492213 --> 0.492188).  Saving model ...
# 972 0.48003703355789185 0.8830986022949219 0.49218815565109253 0.8707864880561829 0.5378932952880859 0.8530183434486389
# Validation loss decreased (0.492188 --> 0.492164).  Saving model ...
# 973 0.4799959361553192 0.8830986022949219 0.4921637177467346 0.8707864880561829 0.5378640294075012 0.8530183434486389
# Validation loss decreased (0.492164 --> 0.492139).  Saving model ...
# 974 0.47995489835739136 0.8830986022949219 0.49213916063308716 0.8707864880561829 0.5378344655036926 0.8530183434486389
# Validation loss decreased (0.492139 --> 0.492115).  Saving model ...
# 975 0.47991371154785156 0.8830986022949219 0.49211451411247253 0.8707864880561829 0.5378053784370422 0.8530183434486389
# Validation loss decreased (0.492115 --> 0.492090).  Saving model ...
# 976 0.47987285256385803 0.8830986022949219 0.49209022521972656 0.8707864880561829 0.5377762317657471 0.8530183434486389
# Validation loss decreased (0.492090 --> 0.492066).  Saving model ...
# 977 0.47983136773109436 0.8830986022949219 0.4920659363269806 0.8707864880561829 0.5377468466758728 0.8530183434486389
# Validation loss decreased (0.492066 --> 0.492042).  Saving model ...
# 978 0.47979122400283813 0.8830986022949219 0.49204152822494507 0.8707864880561829 0.5377179980278015 0.8530183434486389
# Validation loss decreased (0.492042 --> 0.492017).  Saving model ...
# 979 0.47975048422813416 0.8830986022949219 0.49201712012290955 0.8707864880561829 0.5376887321472168 0.8530183434486389
# Validation loss decreased (0.492017 --> 0.491993).  Saving model ...
# 980 0.4797097444534302 0.8830986022949219 0.4919930398464203 0.8707864880561829 0.537659764289856 0.8530183434486389
# Validation loss decreased (0.491993 --> 0.491969).  Saving model ...
# 981 0.4796690046787262 0.8830986022949219 0.49196887016296387 0.8707864880561829 0.5376309156417847 0.8530183434486389
# Validation loss decreased (0.491969 --> 0.491945).  Saving model ...
# 982 0.4796282947063446 0.8830986022949219 0.49194470047950745 0.8707864880561829 0.5376019477844238 0.8530183434486389
# Validation loss decreased (0.491945 --> 0.491921).  Saving model ...
# 983 0.4795880615711212 0.8830986022949219 0.49192067980766296 0.8707864880561829 0.5375727415084839 0.8530183434486389
# Validation loss decreased (0.491921 --> 0.491897).  Saving model ...
# 984 0.4795471429824829 0.8830986022949219 0.49189671874046326 0.8707864880561829 0.5375442504882812 0.8530183434486389
# Validation loss decreased (0.491897 --> 0.491873).  Saving model ...
# 985 0.4795064926147461 0.8830986022949219 0.49187272787094116 0.8707864880561829 0.5375150442123413 0.8530183434486389
# Validation loss decreased (0.491873 --> 0.491849).  Saving model ...
# 986 0.47946593165397644 0.8830986022949219 0.49184882640838623 0.8707864880561829 0.5374865531921387 0.8530183434486389
# Validation loss decreased (0.491849 --> 0.491825).  Saving model ...
# 987 0.4794260263442993 0.8830986022949219 0.4918249547481537 0.8707864880561829 0.5374577641487122 0.8530183434486389
# Validation loss decreased (0.491825 --> 0.491801).  Saving model ...
# 988 0.4793855845928192 0.8830986022949219 0.49180105328559875 0.8707864880561829 0.5374289155006409 0.8530183434486389
# Validation loss decreased (0.491801 --> 0.491777).  Saving model ...
# 989 0.4793449640274048 0.8830986022949219 0.4917772710323334 0.8707864880561829 0.5374006032943726 0.8530183434486389
# Validation loss decreased (0.491777 --> 0.491753).  Saving model ...
# 990 0.47930464148521423 0.8830986022949219 0.4917534589767456 0.8707864880561829 0.5373719334602356 0.8530183434486389
# Validation loss decreased (0.491753 --> 0.491730).  Saving model ...
# 991 0.4792645573616028 0.8830986022949219 0.4917299151420593 0.8707864880561829 0.5373433232307434 0.8530183434486389
# Validation loss decreased (0.491730 --> 0.491706).  Saving model ...
# 992 0.4792245924472809 0.8830986022949219 0.4917061924934387 0.8707864880561829 0.537314772605896 0.8530183434486389
# Validation loss decreased (0.491706 --> 0.491683).  Saving model ...
# 993 0.47918418049812317 0.8830986022949219 0.49168264865875244 0.8707864880561829 0.5372864603996277 0.8530183434486389
# Validation loss decreased (0.491683 --> 0.491659).  Saving model ...
# 994 0.4791438579559326 0.8830986022949219 0.49165913462638855 0.8707864880561829 0.537257730960846 0.8530183434486389
# Validation loss decreased (0.491659 --> 0.491635).  Saving model ...
# 995 0.4791041612625122 0.8830986022949219 0.49163544178009033 0.8707864880561829 0.5372295379638672 0.8530183434486389
# Validation loss decreased (0.491635 --> 0.491612).  Saving model ...
# 996 0.4790637791156769 0.8830986022949219 0.4916120767593384 0.8707864880561829 0.5372012257575989 0.8530183434486389
# Validation loss decreased (0.491612 --> 0.491589).  Saving model ...
# 997 0.4790240228176117 0.8830986022949219 0.4915887713432312 0.8707864880561829 0.5371729135513306 0.8530183434486389
# Validation loss decreased (0.491589 --> 0.491565).  Saving model ...
# 998 0.47898417711257935 0.8830986022949219 0.4915653467178345 0.8707864880561829 0.5371448993682861 0.8530183434486389
# Validation loss decreased (0.491565 --> 0.491542).  Saving model ...
# 999 0.47894424200057983 0.8830986022949219 0.4915420413017273 0.8707864880561829 0.5371165871620178 0.8530183434486389
# <All keys matched successfully>

# %%
print(Precision(prediction, Y_train_tensor))
print(Precision(val_prediction, Y_valid_tensor))
print(Precision(test_prediction, Y_test_tensor))
# Out:
# [0.9632353186607361, 0.6204819083213806]
# [0.9428571462631226, 0.6052631735801697]
# [0.9309210777282715, 0.5454545617103577]

# %%
print(Recall(prediction, Y_train_tensor))
print(Recall(val_prediction, Y_valid_tensor))
print(Recall(test_prediction, Y_test_tensor))
# Out:
# [0.8926746249198914, 0.8373983502388]
# [0.8979591727256775, 0.7419354915618896]
# [0.8899371027946472, 0.6666666865348816]

# %%
print(Accuracy(prediction, Y_train_tensor))
print(Accuracy(val_prediction, Y_valid_tensor))
print(Accuracy(test_prediction, Y_test_tensor))
# Out:
# 0.8830986022949219
# 0.8707864880561829
# 0.8530183434486389
