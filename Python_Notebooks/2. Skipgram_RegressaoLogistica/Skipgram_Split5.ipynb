# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import torch

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
def Accuracy(prediction, observation):
  prediction = prediction[:,1]
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  correct = (prediction_class == observation).float().sum()
  accuracy = correct/prediction_class.shape[0]
  return float(accuracy.cpu())

def Precision(prediction, observation):
  prediction = prediction[:,1]
  res = []
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  for label in [0, 1]:
    correct = (prediction_class[prediction_class == label] == observation[prediction_class == label]).float().sum()
    precision = correct/prediction_class[prediction_class == label].shape[0]
    res.append(float(precision.cpu()))
  return res

def Recall(prediction, observation):
  prediction = prediction[:,1]
  res = []
  prediction_class = (torch.reshape(prediction, observation.shape) > 0.5).float()
  for label in [0, 1]:
    correct = (prediction_class[observation == label] == observation[observation == label]).float().sum()
    recall = correct/prediction_class[observation == label].shape[0]
    res.append(float(recall.cpu()))
  return res

# %%
n_split = 5

# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open('/content/drive/My Drive/Data Master/X_train_final', 'rb') as file:
    X_train = pickle.load(file)

with open('/content/drive/My Drive/Data Master/Y_train_final', 'rb') as file:
    Y_train = pickle.load(file)

with open('/content/drive/My Drive/Data Master/X_test_final', 'rb') as file:
    X_test = pickle.load(file)

with open('/content/drive/My Drive/Data Master/Y_test_final', 'rb') as file:
    Y_test = pickle.load(file)

with open('/content/drive/My Drive/Data Master/word_index_final', 'rb') as file:
    word_index = pickle.load(file)

with open('/content/drive/My Drive/Data Master/train_index_final_split_' + str(n_split), 'rb') as file:
    train_index = pickle.load(file)

with open('/content/drive/My Drive/Data Master/valid_index_final_split_' + str(n_split), 'rb') as file:
    valid_index = pickle.load(file)

# %%
inv_word_index = {ix : w for w, ix in word_index.items()}

# %%
errors = []
embeddings_index = {}
f = open('/content/drive/My Drive/Data Master/skip_s50.txt')
for line in f:
    values = line.split()
    word = values[0]
    try:
      coefs = np.asarray(values[1:], dtype='float32')
    except:
      errors.append(line)
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 929595 word vectors.

# %%
print(len(embeddings_index))
print(len(errors))
# Out:
# 929595
# 4

# %%
EMBEDDING_DIM = 50
errors_2 = []
nomatchs = []

X_train_matrix = np.zeros((len(X_train), EMBEDDING_DIM))
X_test_matrix = np.zeros((len(X_test), EMBEDDING_DIM))

# %%
for i, x in enumerate(X_train):
  for w in x:
    embedding_vector = embeddings_index.get(inv_word_index[w])
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        try:
          X_train_matrix[i] += embedding_vector
        except:
          errors_2.append([word, len(embedding_vector), embedding_vector])
    else:
      nomatchs.append(word)

# %%
for i, x in enumerate(X_test):
  for w in x:
    embedding_vector = embeddings_index.get(inv_word_index[w])
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        try:
          X_test_matrix[i] += embedding_vector
        except:
          errors_2.append([word, len(embedding_vector), embedding_vector])
    else:
      nomatchs.append(word)

# %%
X_train_matrix.shape
# Out:
# (888, 50)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
input_dim = X_train_matrix.shape[1]
input_dim
# Out:
# 50

# %%
class LogisticRegression (nn.Module):

  def __init__(self):
    super(LogisticRegression, self).__init__()

    self.fc1 = nn.Linear(input_dim, 2)
                                
    self.softmax = nn.Softmax(dim=1)

  def forward(self, x):
    x = F.normalize(x)
    y = self.softmax(self.fc1(x))

    return y

# %%
X_train_tensor = torch.from_numpy(X_train_matrix[train_index]).float()
Y_train_tensor = torch.LongTensor(np.array(Y_train[train_index]))

X_valid_tensor = torch.from_numpy(X_train_matrix[valid_index]).float()
Y_valid_tensor = torch.LongTensor(np.array(Y_train[valid_index]))

X_test_tensor = torch.from_numpy(X_test_matrix).float()
Y_test_tensor = torch.LongTensor(np.array(Y_test))

# %%
model = LogisticRegression()

# %%
torch.manual_seed(0)
np.random.seed(0)

# %%
import torch.optim as optim
optimizer = optim.AdamW(model.parameters(), lr=0.01)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, 'min')

# %%
weights = [sum(Y_train)/len(Y_train), 1-sum(Y_train)/len(Y_train)]
class_weights = torch.FloatTensor(weights)
class_weights
# Out:
# tensor([0.1734, 0.8266])

# %%
criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
patience = 20
early_stopping = EarlyStopping(patience=patience, verbose=True)


for i in range(1000):
  model.train()
  optimizer.zero_grad()
  prediction = model(X_train_tensor)
  loss = criterion(prediction, Y_train_tensor)
  loss.backward()
  optimizer.step()

  accuracy = Accuracy(prediction, Y_train_tensor)

  model.eval()

  val_prediction = model(X_valid_tensor)
  test_prediction = model(X_test_tensor)
  val_loss = criterion(val_prediction, Y_valid_tensor)
  test_loss = criterion(test_prediction, Y_test_tensor)

  val_accuracy = Accuracy(val_prediction, Y_valid_tensor)
  test_accuracy = Accuracy(test_prediction, Y_test_tensor)

  early_stopping(val_loss, model)

  if early_stopping.early_stop:
    print("Early stopping")
    break

  print(i, float(loss.cpu()), accuracy, float(val_loss.cpu()), val_accuracy, float(test_loss.cpu()), test_accuracy)

  scheduler.step(val_loss)

model.load_state_dict(torch.load('checkpoint.pt'))
# Out:
# Validation loss decreased (inf --> 0.694063).  Saving model ...
# 0 0.6952663660049438 0.8230336904525757 0.6940628886222839 0.7954545617103577 0.6936012506484985 0.808398962020874
# Validation loss decreased (0.694063 --> 0.692996).  Saving model ...
# 1 0.6937335133552551 0.8089887499809265 0.692996084690094 0.2954545319080353 0.6931676864624023 0.32020998001098633
# Validation loss decreased (0.692996 --> 0.691921).  Saving model ...
# 2 0.6925322413444519 0.3272472023963928 0.6919209361076355 0.1818181872367859 0.6926295161247253 0.18110236525535583
# Validation loss decreased (0.691921 --> 0.690745).  Saving model ...
# 3 0.6914284229278564 0.1839887648820877 0.6907445788383484 0.1818181872367859 0.6919089555740356 0.17585301399230957
# Validation loss decreased (0.690745 --> 0.689452).  Saving model ...
# 4 0.6903064846992493 0.18117977678775787 0.6894518136978149 0.1931818127632141 0.6910099387168884 0.19160105288028717
# Validation loss decreased (0.689452 --> 0.688077).  Saving model ...
# 5 0.6891341805458069 0.19382022321224213 0.6880770325660706 0.25 0.6899917721748352 0.24934382736682892
# Validation loss decreased (0.688077 --> 0.686669).  Saving model ...
# 6 0.6879271268844604 0.26123595237731934 0.686668872833252 0.3806818127632141 0.6889216899871826 0.4409448802471161
# Validation loss decreased (0.686669 --> 0.685266).  Saving model ...
# 7 0.686715304851532 0.47050562500953674 0.6852657198905945 0.6193181872367859 0.6878552436828613 0.6036745309829712
# Validation loss decreased (0.685266 --> 0.683889).  Saving model ...
# 8 0.6855211853981018 0.6460674405097961 0.6838892102241516 0.75 0.6868253350257874 0.7244094610214233
# Validation loss decreased (0.683889 --> 0.682545).  Saving model ...
# 9 0.6843521595001221 0.7514045238494873 0.6825453042984009 0.8125 0.6858463287353516 0.7742782235145569
# Validation loss decreased (0.682545 --> 0.681229).  Saving model ...
# 10 0.6832011938095093 0.7991573214530945 0.6812285780906677 0.8409090638160706 0.6849170923233032 0.8005249500274658
# Validation loss decreased (0.681229 --> 0.679932).  Saving model ...
# 11 0.6820527911186218 0.8146067261695862 0.6799320578575134 0.8409090638160706 0.6840301752090454 0.8057742714881897
# Validation loss decreased (0.679932 --> 0.678654).  Saving model ...
# 12 0.6808962821960449 0.817415714263916 0.6786538362503052 0.8465909361839294 0.6831782460212708 0.8110235929489136
# Validation loss decreased (0.678654 --> 0.677395).  Saving model ...
# 13 0.6797314286231995 0.8188202381134033 0.6773946285247803 0.8238636255264282 0.6823568940162659 0.7769029140472412
# Validation loss decreased (0.677395 --> 0.676156).  Saving model ...
# 14 0.6785624027252197 0.8061797618865967 0.6761555671691895 0.7897727489471436 0.6815606355667114 0.76115483045578
# Validation loss decreased (0.676156 --> 0.674934).  Saving model ...
# 15 0.6774000525474548 0.7823033928871155 0.6749341487884521 0.7556818127632141 0.6807819604873657 0.748031497001648
# Validation loss decreased (0.674934 --> 0.673722).  Saving model ...
# 16 0.6762487888336182 0.7626404762268066 0.6737222075462341 0.7556818127632141 0.6800079345703125 0.7244094610214233
# Validation loss decreased (0.673722 --> 0.672509).  Saving model ...
# 17 0.6751117706298828 0.7387640476226807 0.672508955001831 0.7443181872367859 0.6792239546775818 0.6929134130477905
# Validation loss decreased (0.672509 --> 0.671283).  Saving model ...
# 18 0.673983097076416 0.716292142868042 0.6712828874588013 0.7329545617103577 0.6784182190895081 0.6876640319824219
# Validation loss decreased (0.671283 --> 0.670039).  Saving model ...
# 19 0.6728588342666626 0.7078651785850525 0.6700392365455627 0.7386363744735718 0.6775864362716675 0.6902887225151062
# Validation loss decreased (0.670039 --> 0.668779).  Saving model ...
# 20 0.6717362999916077 0.716292142868042 0.6687790751457214 0.7443181872367859 0.6767322421073914 0.7060367465019226
# Validation loss decreased (0.668779 --> 0.667511).  Saving model ...
# 21 0.6706144213676453 0.7275280952453613 0.6675105690956116 0.75 0.6758655309677124 0.7401574850082397
# Validation loss decreased (0.667511 --> 0.666243).  Saving model ...
# 22 0.6694974899291992 0.7485954761505127 0.6662434935569763 0.7727272510528564 0.6749988794326782 0.7506561875343323
# Validation loss decreased (0.666243 --> 0.664987).  Saving model ...
# 23 0.6683895587921143 0.7598314881324768 0.6649868488311768 0.7784090638160706 0.6741436123847961 0.7559055089950562
# Validation loss decreased (0.664987 --> 0.663747).  Saving model ...
# 24 0.6672924757003784 0.7766854166984558 0.6637465953826904 0.8011363744735718 0.6733066439628601 0.7664042115211487
# Validation loss decreased (0.663747 --> 0.662526).  Saving model ...
# 25 0.6662047505378723 0.7865168452262878 0.6625257134437561 0.8068181872367859 0.6724920272827148 0.7690288424491882
# Validation loss decreased (0.662526 --> 0.661325).  Saving model ...
# 26 0.6651241183280945 0.7893258333206177 0.6613250374794006 0.8125 0.6717008352279663 0.7690288424491882
# Validation loss decreased (0.661325 --> 0.660145).  Saving model ...
# 27 0.6640487313270569 0.7921348214149475 0.6601445078849792 0.8068181872367859 0.6709303855895996 0.7690288424491882
# Validation loss decreased (0.660145 --> 0.658983).  Saving model ...
# 28 0.6629784107208252 0.7879213690757751 0.6589825749397278 0.8011363744735718 0.6701791286468506 0.7664042115211487
# Validation loss decreased (0.658983 --> 0.657837).  Saving model ...
# 29 0.661914587020874 0.783707857131958 0.6578369140625 0.7897727489471436 0.6694422960281372 0.7585301995277405
# Validation loss decreased (0.657837 --> 0.656703).  Saving model ...
# 30 0.6608582735061646 0.783707857131958 0.6567027568817139 0.7784090638160706 0.6687145829200745 0.7559055089950562
# Validation loss decreased (0.656703 --> 0.655574).  Saving model ...
# 31 0.6598119735717773 0.773876428604126 0.6555736660957336 0.7727272510528564 0.6679884195327759 0.7532808184623718
# Validation loss decreased (0.655574 --> 0.654444).  Saving model ...
# 32 0.6587743759155273 0.7752808928489685 0.6544436812400818 0.7727272510528564 0.6672587394714355 0.7506561875343323
# Validation loss decreased (0.654444 --> 0.653310).  Saving model ...
# 33 0.6577450633049011 0.7710674405097961 0.653310239315033 0.7727272510528564 0.6665218472480774 0.7506561875343323
# Validation loss decreased (0.653310 --> 0.652173).  Saving model ...
# 34 0.6567237973213196 0.7724719047546387 0.6521725058555603 0.7727272510528564 0.6657785177230835 0.7506561875343323
# Validation loss decreased (0.652173 --> 0.651034).  Saving model ...
# 35 0.6557077765464783 0.773876428604126 0.6510342955589294 0.7784090638160706 0.6650331020355225 0.7506561875343323
# Validation loss decreased (0.651034 --> 0.649901).  Saving model ...
# 36 0.6546996831893921 0.773876428604126 0.6499013900756836 0.8011363744735718 0.6642906665802002 0.7559055089950562
# Validation loss decreased (0.649901 --> 0.648779).  Saving model ...
# 37 0.6537002325057983 0.7766854166984558 0.6487786769866943 0.8011363744735718 0.6635568141937256 0.7637795209884644
# Validation loss decreased (0.648779 --> 0.647671).  Saving model ...
# 38 0.6527106761932373 0.783707857131958 0.6476708054542542 0.8238636255264282 0.662837028503418 0.7664042115211487
# Validation loss decreased (0.647671 --> 0.646580).  Saving model ...
# 39 0.6517294049263 0.7879213690757751 0.6465803980827332 0.8238636255264282 0.6621318459510803 0.7690288424491882
# Validation loss decreased (0.646580 --> 0.645508).  Saving model ...
# 40 0.6507554650306702 0.7893258333206177 0.6455081701278687 0.8238636255264282 0.6614420413970947 0.7690288424491882
# Validation loss decreased (0.645508 --> 0.644453).  Saving model ...
# 41 0.6497888565063477 0.7893258333206177 0.6444531083106995 0.8181818127632141 0.6607666015625 0.7637795209884644
# Validation loss decreased (0.644453 --> 0.643413).  Saving model ...
# 42 0.6488304138183594 0.7893258333206177 0.6434125900268555 0.8181818127632141 0.6601022481918335 0.7637795209884644
# Validation loss decreased (0.643413 --> 0.642384).  Saving model ...
# 43 0.6478803157806396 0.7865168452262878 0.6423836350440979 0.8011363744735718 0.6594462394714355 0.76115483045578
# Validation loss decreased (0.642384 --> 0.641361).  Saving model ...
# 44 0.6469380855560303 0.7808988690376282 0.6413610577583313 0.8011363744735718 0.6587942838668823 0.76115483045578
# Validation loss decreased (0.641361 --> 0.640342).  Saving model ...
# 45 0.646004855632782 0.7780898809432983 0.6403420567512512 0.8011363744735718 0.6581425070762634 0.76115483045578
# Validation loss decreased (0.640342 --> 0.639324).  Saving model ...
# 46 0.645079493522644 0.7780898809432983 0.6393240690231323 0.8011363744735718 0.657490074634552 0.76115483045578
# Validation loss decreased (0.639324 --> 0.638308).  Saving model ...
# 47 0.6441617012023926 0.7780898809432983 0.6383075714111328 0.8068181872367859 0.6568373441696167 0.76115483045578
# Validation loss decreased (0.638308 --> 0.637294).  Saving model ...
# 48 0.6432520747184753 0.7808988690376282 0.6372944712638855 0.8181818127632141 0.6561864018440247 0.76115483045578
# Validation loss decreased (0.637294 --> 0.636289).  Saving model ...
# 49 0.6423503160476685 0.7851123809814453 0.6362892985343933 0.8181818127632141 0.6555395722389221 0.76115483045578
# Validation loss decreased (0.636289 --> 0.635295).  Saving model ...
# 50 0.6414563655853271 0.7865168452262878 0.635295033454895 0.8181818127632141 0.6549016237258911 0.7637795209884644
# Validation loss decreased (0.635295 --> 0.634314).  Saving model ...
# 51 0.6405704617500305 0.7893258333206177 0.6343141794204712 0.8238636255264282 0.6542731523513794 0.7664042115211487
# Validation loss decreased (0.634314 --> 0.633349).  Saving model ...
# 52 0.6396929621696472 0.7893258333206177 0.6333487629890442 0.8238636255264282 0.653656005859375 0.7664042115211487
# Validation loss decreased (0.633349 --> 0.632398).  Saving model ...
# 53 0.6388223767280579 0.7893258333206177 0.6323978304862976 0.8238636255264282 0.6530495285987854 0.7664042115211487
# Validation loss decreased (0.632398 --> 0.631460).  Saving model ...
# 54 0.637959897518158 0.7893258333206177 0.6314601898193359 0.8238636255264282 0.652452290058136 0.7664042115211487
# Validation loss decreased (0.631460 --> 0.630533).  Saving model ...
# 55 0.6371054649353027 0.7879213690757751 0.6305332183837891 0.8181818127632141 0.6518617272377014 0.76115483045578
# Validation loss decreased (0.630533 --> 0.629614).  Saving model ...
# 56 0.6362578272819519 0.7879213690757751 0.6296138167381287 0.8181818127632141 0.6512757539749146 0.76115483045578
# Validation loss decreased (0.629614 --> 0.628699).  Saving model ...
# 57 0.635418176651001 0.7879213690757751 0.6286993026733398 0.8181818127632141 0.650692343711853 0.76115483045578
# Validation loss decreased (0.628699 --> 0.627788).  Saving model ...
# 58 0.6345860362052917 0.7879213690757751 0.6277881264686584 0.8181818127632141 0.650109589099884 0.76115483045578
# Validation loss decreased (0.627788 --> 0.626881).  Saving model ...
# 59 0.6337611675262451 0.7893258333206177 0.6268808245658875 0.8238636255264282 0.6495288610458374 0.76115483045578
# Validation loss decreased (0.626881 --> 0.625979).  Saving model ...
# 60 0.6329438090324402 0.7893258333206177 0.6259790658950806 0.8238636255264282 0.6489508748054504 0.7637795209884644
# Validation loss decreased (0.625979 --> 0.625084).  Saving model ...
# 61 0.6321332454681396 0.7893258333206177 0.625084400177002 0.8238636255264282 0.6483767032623291 0.7637795209884644
# Validation loss decreased (0.625084 --> 0.624200).  Saving model ...
# 62 0.6313298344612122 0.790730357170105 0.6241999268531799 0.8238636255264282 0.647809624671936 0.7664042115211487
# Validation loss decreased (0.624200 --> 0.623327).  Saving model ...
# 63 0.6305342316627502 0.7921348214149475 0.6233273148536682 0.8238636255264282 0.6472501754760742 0.7664042115211487
# Validation loss decreased (0.623327 --> 0.622467).  Saving model ...
# 64 0.6297448873519897 0.7921348214149475 0.6224667429924011 0.8238636255264282 0.6466984152793884 0.7690288424491882
# Validation loss decreased (0.622467 --> 0.621618).  Saving model ...
# 65 0.6289634108543396 0.7921348214149475 0.6216184496879578 0.8238636255264282 0.6461547017097473 0.7690288424491882
# Validation loss decreased (0.621618 --> 0.620780).  Saving model ...
# 66 0.6281880736351013 0.7921348214149475 0.620779812335968 0.8181818127632141 0.6456168293952942 0.7664042115211487
# Validation loss decreased (0.620780 --> 0.619950).  Saving model ...
# 67 0.627419114112854 0.7921348214149475 0.6199497580528259 0.8181818127632141 0.6450839638710022 0.7664042115211487
# Validation loss decreased (0.619950 --> 0.619126).  Saving model ...
# 68 0.6266576647758484 0.7921348214149475 0.6191255450248718 0.8181818127632141 0.6445544362068176 0.7664042115211487
# Validation loss decreased (0.619126 --> 0.618307).  Saving model ...
# 69 0.6259026527404785 0.7921348214149475 0.6183066368103027 0.8181818127632141 0.6440272927284241 0.7664042115211487
# Validation loss decreased (0.618307 --> 0.617492).  Saving model ...
# 70 0.625154435634613 0.7921348214149475 0.6174917221069336 0.8181818127632141 0.6435015201568604 0.7664042115211487
# Validation loss decreased (0.617492 --> 0.616682).  Saving model ...
# 71 0.6244125366210938 0.7921348214149475 0.6166821718215942 0.8181818127632141 0.6429781913757324 0.7664042115211487
# Validation loss decreased (0.616682 --> 0.615879).  Saving model ...
# 72 0.6236763000488281 0.7921348214149475 0.6158789992332458 0.8181818127632141 0.6424589157104492 0.7716535329818726
# Validation loss decreased (0.615879 --> 0.615084).  Saving model ...
# 73 0.6229473352432251 0.7921348214149475 0.6150839924812317 0.8238636255264282 0.6419447064399719 0.7742782235145569
# Validation loss decreased (0.615084 --> 0.614298).  Saving model ...
# 74 0.6222240924835205 0.7921348214149475 0.6142982244491577 0.8238636255264282 0.6414350271224976 0.7742782235145569
# Validation loss decreased (0.614298 --> 0.613523).  Saving model ...
# 75 0.6215072274208069 0.7921348214149475 0.6135225892066956 0.8238636255264282 0.6409319639205933 0.7742782235145569
# Validation loss decreased (0.613523 --> 0.612757).  Saving model ...
# 76 0.6207960844039917 0.7921348214149475 0.6127567291259766 0.8238636255264282 0.6404344439506531 0.7742782235145569
# Validation loss decreased (0.612757 --> 0.611999).  Saving model ...
# 77 0.620091438293457 0.7921348214149475 0.6119992733001709 0.8238636255264282 0.6399425864219666 0.7742782235145569
# Validation loss decreased (0.611999 --> 0.611249).  Saving model ...
# 78 0.6193928718566895 0.7921348214149475 0.6112494468688965 0.8238636255264282 0.639454185962677 0.7742782235145569
# Validation loss decreased (0.611249 --> 0.610505).  Saving model ...
# 79 0.618699312210083 0.7921348214149475 0.6105054616928101 0.8238636255264282 0.6389691233634949 0.7742782235145569
# Validation loss decreased (0.610505 --> 0.609766).  Saving model ...
# 80 0.6180122494697571 0.7935393452644348 0.6097664833068848 0.8238636255264282 0.6384860277175903 0.7742782235145569
# Validation loss decreased (0.609766 --> 0.609033).  Saving model ...
# 81 0.6173303127288818 0.7935393452644348 0.6090325117111206 0.8238636255264282 0.6380054950714111 0.7742782235145569
# Validation loss decreased (0.609033 --> 0.608303).  Saving model ...
# 82 0.6166544556617737 0.7949438095092773 0.6083031892776489 0.8238636255264282 0.6375274062156677 0.7795275449752808
# Validation loss decreased (0.608303 --> 0.607580).  Saving model ...
# 83 0.6159840226173401 0.7949438095092773 0.6075802445411682 0.8238636255264282 0.637052059173584 0.787401556968689
# Validation loss decreased (0.607580 --> 0.606864).  Saving model ...
# 84 0.6153189539909363 0.7949438095092773 0.606864333152771 0.8238636255264282 0.6365813612937927 0.787401556968689
# Validation loss decreased (0.606864 --> 0.606156).  Saving model ...
# 85 0.6146591901779175 0.7949438095092773 0.6061561703681946 0.8238636255264282 0.6361143589019775 0.787401556968689
# Validation loss decreased (0.606156 --> 0.605456).  Saving model ...
# 86 0.6140049695968628 0.7949438095092773 0.6054562330245972 0.8238636255264282 0.6356523036956787 0.787401556968689
# Validation loss decreased (0.605456 --> 0.604764).  Saving model ...
# 87 0.613355815410614 0.7963483333587646 0.6047640442848206 0.8238636255264282 0.6351945400238037 0.787401556968689
# Validation loss decreased (0.604764 --> 0.604079).  Saving model ...
# 88 0.612712025642395 0.7963483333587646 0.604079008102417 0.8238636255264282 0.6347411274909973 0.787401556968689
# Validation loss decreased (0.604079 --> 0.603400).  Saving model ...
# 89 0.6120737195014954 0.7963483333587646 0.6034001708030701 0.8238636255264282 0.6342905163764954 0.787401556968689
# Validation loss decreased (0.603400 --> 0.602727).  Saving model ...
# 90 0.6114400029182434 0.7963483333587646 0.6027265191078186 0.8295454382896423 0.6338419914245605 0.7847769260406494
# Validation loss decreased (0.602727 --> 0.602058).  Saving model ...
# 91 0.6108112931251526 0.7977527976036072 0.602057695388794 0.8295454382896423 0.6333964467048645 0.7847769260406494
# Validation loss decreased (0.602058 --> 0.601394).  Saving model ...
# 92 0.6101874709129333 0.7977527976036072 0.6013935208320618 0.8352272510528564 0.632952868938446 0.7847769260406494
# Validation loss decreased (0.601394 --> 0.600734).  Saving model ...
# 93 0.6095685958862305 0.7977527976036072 0.6007342338562012 0.8352272510528564 0.6325120329856873 0.7847769260406494
# Validation loss decreased (0.600734 --> 0.600081).  Saving model ...
# 94 0.6089547276496887 0.7991573214530945 0.6000809073448181 0.8352272510528564 0.6320743560791016 0.7847769260406494
# Validation loss decreased (0.600081 --> 0.599434).  Saving model ...
# 95 0.6083452701568604 0.7991573214530945 0.5994338393211365 0.8352272510528564 0.6316398978233337 0.787401556968689
# Validation loss decreased (0.599434 --> 0.598793).  Saving model ...
# 96 0.6077407002449036 0.800561785697937 0.5987931489944458 0.8352272510528564 0.6312087774276733 0.7900262475013733
# Validation loss decreased (0.598793 --> 0.598159).  Saving model ...
# 97 0.6071407794952393 0.800561785697937 0.5981592535972595 0.8352272510528564 0.6307815313339233 0.7900262475013733
# Validation loss decreased (0.598159 --> 0.597532).  Saving model ...
# 98 0.6065448522567749 0.800561785697937 0.5975318551063538 0.8352272510528564 0.6303579807281494 0.7900262475013733
# Validation loss decreased (0.597532 --> 0.596910).  Saving model ...
# 99 0.6059539914131165 0.800561785697937 0.5969099998474121 0.8352272510528564 0.6299368739128113 0.7900262475013733
# Validation loss decreased (0.596910 --> 0.596294).  Saving model ...
# 100 0.6053676009178162 0.800561785697937 0.596293568611145 0.8352272510528564 0.6295183897018433 0.7900262475013733
# Validation loss decreased (0.596294 --> 0.595681).  Saving model ...
# 101 0.6047856211662292 0.800561785697937 0.5956811904907227 0.8352272510528564 0.6291025280952454 0.7900262475013733
# Validation loss decreased (0.595681 --> 0.595073).  Saving model ...
# 102 0.6042075157165527 0.800561785697937 0.5950734615325928 0.8352272510528564 0.6286888122558594 0.7900262475013733
# Validation loss decreased (0.595073 --> 0.594470).  Saving model ...
# 103 0.6036340594291687 0.800561785697937 0.5944703221321106 0.8352272510528564 0.6282772421836853 0.7900262475013733
# Validation loss decreased (0.594470 --> 0.593872).  Saving model ...
# 104 0.6030653715133667 0.800561785697937 0.5938718914985657 0.8352272510528564 0.627868115901947 0.7926509380340576
# Validation loss decreased (0.593872 --> 0.593279).  Saving model ...
# 105 0.6024996042251587 0.800561785697937 0.5932789444923401 0.8352272510528564 0.6274617910385132 0.7926509380340576
# Validation loss decreased (0.593279 --> 0.592691).  Saving model ...
# 106 0.6019384860992432 0.800561785697937 0.5926914811134338 0.8352272510528564 0.6270585060119629 0.7926509380340576
# Validation loss decreased (0.592691 --> 0.592110).  Saving model ...
# 107 0.6013819575309753 0.800561785697937 0.5921095013618469 0.8352272510528564 0.6266587376594543 0.7952755689620972
# Validation loss decreased (0.592110 --> 0.591533).  Saving model ...
# 108 0.600829005241394 0.800561785697937 0.5915330648422241 0.8352272510528564 0.6262611150741577 0.7952755689620972
# Validation loss decreased (0.591533 --> 0.590962).  Saving model ...
# 109 0.6002798080444336 0.800561785697937 0.5909615755081177 0.8352272510528564 0.6258664727210999 0.7952755689620972
# Validation loss decreased (0.590962 --> 0.590395).  Saving model ...
# 110 0.5997352004051208 0.8019663095474243 0.5903947949409485 0.8352272510528564 0.6254745721817017 0.7952755689620972
# Validation loss decreased (0.590395 --> 0.589832).  Saving model ...
# 111 0.599194347858429 0.8061797618865967 0.5898323059082031 0.8352272510528564 0.6250849366188049 0.7952755689620972
# Validation loss decreased (0.589832 --> 0.589274).  Saving model ...
# 112 0.5986574292182922 0.8061797618865967 0.589273989200592 0.8352272510528564 0.6246964335441589 0.7952755689620972
# Validation loss decreased (0.589274 --> 0.588720).  Saving model ...
# 113 0.5981234908103943 0.8061797618865967 0.5887196063995361 0.8352272510528564 0.6243110299110413 0.7952755689620972
# Validation loss decreased (0.588720 --> 0.588170).  Saving model ...
# 114 0.5975939631462097 0.8061797618865967 0.5881696939468384 0.8352272510528564 0.6239274740219116 0.7952755689620972
# Validation loss decreased (0.588170 --> 0.587624).  Saving model ...
# 115 0.5970685482025146 0.8061797618865967 0.5876242518424988 0.8352272510528564 0.6235465407371521 0.7952755689620972
# Validation loss decreased (0.587624 --> 0.587084).  Saving model ...
# 116 0.596545934677124 0.8061797618865967 0.5870835781097412 0.8409090638160706 0.6231679320335388 0.7952755689620972
# Validation loss decreased (0.587084 --> 0.586548).  Saving model ...
# 117 0.5960274934768677 0.807584285736084 0.5865478515625 0.8409090638160706 0.6227921843528748 0.7979002594947815
# Validation loss decreased (0.586548 --> 0.586017).  Saving model ...
# 118 0.5955123901367188 0.807584285736084 0.5860167145729065 0.8409090638160706 0.6224187016487122 0.7979002594947815
# Validation loss decreased (0.586017 --> 0.585490).  Saving model ...
# 119 0.5950007438659668 0.807584285736084 0.585489809513092 0.8465909361839294 0.6220479607582092 0.7979002594947815
# Validation loss decreased (0.585490 --> 0.584967).  Saving model ...
# 120 0.5944927930831909 0.807584285736084 0.5849672555923462 0.8465909361839294 0.6216789484024048 0.7979002594947815
# Validation loss decreased (0.584967 --> 0.584449).  Saving model ...
# 121 0.5939883589744568 0.807584285736084 0.5844485759735107 0.8522727489471436 0.6213124990463257 0.7979002594947815
# Validation loss decreased (0.584449 --> 0.583934).  Saving model ...
# 122 0.5934875011444092 0.807584285736084 0.5839336514472961 0.8522727489471436 0.6209480166435242 0.7979002594947815
# Validation loss decreased (0.583934 --> 0.583422).  Saving model ...
# 123 0.5929899215698242 0.8089887499809265 0.5834224820137024 0.8522727489471436 0.6205853223800659 0.7952755689620972
# Validation loss decreased (0.583422 --> 0.582915).  Saving model ...
# 124 0.5924957394599915 0.8103932738304138 0.582915186882019 0.8522727489471436 0.6202245354652405 0.7979002594947815
# Validation loss decreased (0.582915 --> 0.582412).  Saving model ...
# 125 0.592004656791687 0.8103932738304138 0.5824118256568909 0.8522727489471436 0.6198663115501404 0.7979002594947815
# Validation loss decreased (0.582412 --> 0.581913).  Saving model ...
# 126 0.5915167331695557 0.8103932738304138 0.5819125175476074 0.8522727489471436 0.6195101141929626 0.7952755689620972
# Validation loss decreased (0.581913 --> 0.581417).  Saving model ...
# 178 0.5699784755706787 0.824438214302063 0.560408353805542 0.8352272510528564 0.6035312414169312 0.8057742714881897
# Validation loss decreased (0.560408 --> 0.560065).  Saving model ...
# 179 0.5696262121200562 0.8258426785469055 0.5600653886795044 0.8409090638160706 0.6032659411430359 0.8057742714881897
# Validation loss decreased (0.560065 --> 0.559725).  Saving model ...
# 180 0.5692757368087769 0.8258426785469055 0.5597245097160339 0.8409090638160706 0.6030021905899048 0.8057742714881897
# Validation loss decreased (0.559725 --> 0.559386).  Saving model ...
# 181 0.5689276456832886 0.8272472023963928 0.5593858361244202 0.8409090638160706 0.6027399897575378 0.8057742714881897
# Validation loss decreased (0.559386 --> 0.559049).  Saving model ...
# 182 0.5685812830924988 0.8272472023963928 0.559049129486084 0.8409090638160706 0.6024788618087769 0.808398962020874
# Validation loss decreased (0.559049 --> 0.558715).  Saving model ...
# 183 0.568236768245697 0.8286516666412354 0.5587148666381836 0.8409090638160706 0.6022192239761353 0.808398962020874
# Validation loss decreased (0.558715 --> 0.558383).  Saving model ...
# 184 0.5678945183753967 0.8286516666412354 0.5583825707435608 0.8409090638160706 0.6019609570503235 0.808398962020874
# Validation loss decreased (0.558383 --> 0.558052).  Saving model ...
# 185 0.5675539374351501 0.8286516666412354 0.5580524802207947 0.8409090638160706 0.6017041206359863 0.8110235929489136
# Validation loss decreased (0.558052 --> 0.557724).  Saving model ...
# 186 0.5672153234481812 0.8314606547355652 0.5577242374420166 0.8409090638160706 0.6014483571052551 0.8110235929489136
# Validation loss decreased (0.557724 --> 0.557398).  Saving model ...
# 187 0.566878080368042 0.8328651785850525 0.5573982000350952 0.8465909361839294 0.6011943221092224 0.8110235929489136
# Validation loss decreased (0.557398 --> 0.557074).  Saving model ...
# 188 0.5665432214736938 0.8328651785850525 0.557074248790741 0.8465909361839294 0.6009413599967957 0.8110235929489136
# Validation loss decreased (0.557074 --> 0.556752).  Saving model ...
# 189 0.5662099123001099 0.8328651785850525 0.5567521452903748 0.8465909361839294 0.6006894111633301 0.8110235929489136
# Validation loss decreased (0.556752 --> 0.556432).  Saving model ...
# 190 0.5658786296844482 0.8328651785850525 0.5564323663711548 0.8465909361839294 0.6004390120506287 0.8136482834815979
# Validation loss decreased (0.556432 --> 0.556114).  Saving model ...
# 191 0.5655488967895508 0.8328651785850525 0.5561142563819885 0.8465909361839294 0.6001899242401123 0.8136482834815979
# Validation loss decreased (0.556114 --> 0.555798).  Saving model ...
# 192 0.5652209520339966 0.834269642829895 0.5557981133460999 0.8465909361839294 0.5999420881271362 0.8136482834815979
# Validation loss decreased (0.555798 --> 0.555484).  Saving model ...
# 193 0.56489497423172 0.834269642829895 0.5554839968681335 0.8465909361839294 0.5996952652931213 0.8136482834815979
# Validation loss decreased (0.555484 --> 0.555172).  Saving model ...
# 194 0.5645706653594971 0.834269642829895 0.5551718473434448 0.8465909361839294 0.5994500517845154 0.8136482834815979
# Validation loss decreased (0.555172 --> 0.554862).  Saving model ...
# 212 0.5590193867683411 0.8398876190185547 0.5498653054237366 0.8522727489471436 0.595238208770752 0.8162729740142822
# Validation loss decreased (0.549865 --> 0.549586).  Saving model ...
# 213 0.5587257742881775 0.8398876190185547 0.5495864748954773 0.8522727489471436 0.5950151085853577 0.8188976645469666
# Validation loss decreased (0.549586 --> 0.549310).  Saving model ...
# 214 0.5584335327148438 0.8398876190185547 0.5493097305297852 0.8522727489471436 0.594792902469635 0.8188976645469666
# Validation loss decreased (0.549310 --> 0.549035).  Saving model ...
# 215 0.5581435561180115 0.841292142868042 0.5490345358848572 0.8522727489471436 0.5945722460746765 0.8188976645469666
# Validation loss decreased (0.549035 --> 0.548761).  Saving model ...
# 216 0.557854175567627 0.841292142868042 0.5487609505653381 0.8522727489471436 0.5943524241447449 0.8188976645469666
# Validation loss decreased (0.548761 --> 0.548489).  Saving model ...
# 217 0.5575665831565857 0.841292142868042 0.5484885573387146 0.8522727489471436 0.5941335558891296 0.8188976645469666
# Validation loss decreased (0.548489 --> 0.548218).  Saving model ...
# 218 0.5572806596755981 0.841292142868042 0.5482182502746582 0.8522727489471436 0.5939158797264099 0.8188976645469666
# Validation loss decreased (0.548218 --> 0.547949).  Saving model ...
# 219 0.5569961071014404 0.841292142868042 0.5479493141174316 0.8522727489471436 0.5936989188194275 0.8188976645469666
# Validation loss decreased (0.547949 --> 0.547682).  Saving model ...
# 220 0.556712806224823 0.841292142868042 0.5476819276809692 0.8522727489471436 0.5934835076332092 0.8188976645469666
# Validation loss decreased (0.547682 --> 0.547416).  Saving model ...
# 221 0.5564310550689697 0.841292142868042 0.547416090965271 0.8522727489471436 0.593268871307373 0.8188976645469666
# Validation loss decreased (0.547416 --> 0.547152).  Saving model ...
# 222 0.5561508536338806 0.8398876190185547 0.547151505947113 0.8522727489471436 0.5930553674697876 0.8188976645469666
# Validation loss decreased (0.547152 --> 0.546889).  Saving model ...
# 223 0.5558717250823975 0.8398876190185547 0.5468886494636536 0.8522727489471436 0.592842698097229 0.8188976645469666
# Validation loss decreased (0.546889 --> 0.546627).  Saving model ...
# 224 0.5555939078330994 0.8398876190185547 0.546627402305603 0.8522727489471436 0.5926313400268555 0.8188976645469666
# Validation loss decreased (0.546627 --> 0.546368).  Saving model ...
# 225 0.5553174614906311 0.8398876190185547 0.5463676452636719 0.8522727489471436 0.5924206376075745 0.8188976645469666
# Validation loss decreased (0.546368 --> 0.546109).  Saving model ...
# 226 0.5550428032875061 0.8398876190185547 0.5461090803146362 0.8522727489471436 0.5922113060951233 0.8188976645469666
# Validation loss decreased (0.546109 --> 0.545852).  Saving model ...
# 227 0.5547690391540527 0.8398876190185547 0.5458522439002991 0.8522727489471436 0.5920028686523438 0.8188976645469666
# Validation loss decreased (0.545852 --> 0.545597).  Saving model ...
# 228 0.554497241973877 0.8398876190185547 0.5455967783927917 0.8522727489471436 0.5917954444885254 0.8215222954750061
# Validation loss decreased (0.545597 --> 0.545343).  Saving model ...
# 229 0.5542265772819519 0.8398876190185547 0.545342743396759 0.8522727489471436 0.5915887355804443 0.8215222954750061
# Validation loss decreased (0.545343 --> 0.545090).  Saving model ...
# 230 0.5539565086364746 0.8398876190185547 0.5450899600982666 0.8522727489471436 0.5913834571838379 0.8215222954750061
# Validation loss decreased (0.545090 --> 0.544839).  Saving model ...
# 231 0.5536885857582092 0.8398876190185547 0.5448387265205383 0.8522727489471436 0.5911787152290344 0.8215222954750061
# Validation loss decreased (0.544839 --> 0.544589).  Saving model ...
# 232 0.5534215569496155 0.8398876190185547 0.544589102268219 0.8522727489471436 0.5909751653671265 0.8215222954750061
# Validation loss decreased (0.544589 --> 0.544341).  Saving model ...
# 233 0.5531557202339172 0.8398876190185547 0.5443406701087952 0.8522727489471436 0.5907726287841797 0.8215222954750061
# Validation loss decreased (0.544341 --> 0.544094).  Saving model ...
# 234 0.5528916120529175 0.8398876190185547 0.5440935492515564 0.8522727489471436 0.5905709862709045 0.8215222954750061
# Validation loss decreased (0.544094 --> 0.543848).  Saving model ...
# 235 0.5526280403137207 0.8398876190185547 0.5438477396965027 0.8522727489471436 0.590370237827301 0.8241469860076904
# Validation loss decreased (0.543848 --> 0.543604).  Saving model ...
# 236 0.5523666739463806 0.8398876190185547 0.5436037182807922 0.8579545617103577 0.5901700854301453 0.8241469860076904
# Validation loss decreased (0.543604 --> 0.543361).  Saving model ...
# 237 0.5521062612533569 0.8398876190185547 0.5433605313301086 0.8579545617103577 0.5899718403816223 0.8241469860076904
# Validation loss decreased (0.543361 --> 0.543119).  Saving model ...
# 238 0.5518468022346497 0.8398876190185547 0.5431188344955444 0.8579545617103577 0.5897737145423889 0.8267716765403748
# Validation loss decreased (0.543119 --> 0.542879).  Saving model ...
# 239 0.5515884160995483 0.8398876190185547 0.5428785681724548 0.8522727489471436 0.5895767211914062 0.8267716765403748
# Validation loss decreased (0.542879 --> 0.542640).  Saving model ...
# 240 0.5513318181037903 0.8398876190185547 0.5426397323608398 0.8522727489471436 0.58938068151474 0.8267716765403748
# Validation loss decreased (0.542640 --> 0.542402).  Saving model ...
# 241 0.5510759949684143 0.8398876190185547 0.542401909828186 0.8522727489471436 0.5891858339309692 0.8267716765403748
# Validation loss decreased (0.542402 --> 0.542166).  Saving model ...
# 242 0.5508217811584473 0.8398876190185547 0.5421655178070068 0.8522727489471436 0.5889914631843567 0.8267716765403748
# Validation loss decreased (0.542166 --> 0.541931).  Saving model ...
# 243 0.550568699836731 0.8398876190185547 0.5419305562973022 0.8522727489471436 0.5887985229492188 0.8267716765403748
# Validation loss decreased (0.541931 --> 0.541697).  Saving model ...
# 244 0.5503162145614624 0.8398876190185547 0.5416967272758484 0.8522727489471436 0.5886059999465942 0.8293963074684143
# Validation loss decreased (0.541697 --> 0.541464).  Saving model ...
# 245 0.5500656962394714 0.8398876190185547 0.5414641499519348 0.8522727489471436 0.5884143710136414 0.8320209980010986
# Validation loss decreased (0.541464 --> 0.541233).  Saving model ...
# 246 0.549815833568573 0.8398876190185547 0.5412326455116272 0.8522727489471436 0.5882237553596497 0.8320209980010986
# Validation loss decreased (0.541233 --> 0.541003).  Saving model ...
# 247 0.5495671033859253 0.8398876190185547 0.5410028696060181 0.8522727489471436 0.58803391456604 0.8320209980010986
# Validation loss decreased (0.541003 --> 0.540774).  Saving model ...
# 248 0.5493202805519104 0.841292142868042 0.5407737493515015 0.8522727489471436 0.5878447890281677 0.8320209980010986
# Validation loss decreased (0.540774 --> 0.540546).  Saving model ...
# 249 0.5490738153457642 0.841292142868042 0.5405462980270386 0.8522727489471436 0.5876571536064148 0.8320209980010986
# Validation loss decreased (0.540546 --> 0.540320).  Saving model ...
# 250 0.548828661441803 0.841292142868042 0.5403199195861816 0.8522727489471436 0.5874700546264648 0.8320209980010986
# Validation loss decreased (0.540320 --> 0.540095).  Saving model ...
# 251 0.5485847592353821 0.841292142868042 0.5400949120521545 0.8522727489471436 0.5872834324836731 0.8320209980010986
# Validation loss decreased (0.540095 --> 0.539871).  Saving model ...
# 252 0.5483421683311462 0.841292142868042 0.5398710370063782 0.8522727489471436 0.5870983004570007 0.8320209980010986
# Validation loss decreased (0.539871 --> 0.539648).  Saving model ...
# 253 0.5481002330780029 0.841292142868042 0.5396479964256287 0.8522727489471436 0.5869138240814209 0.8320209980010986
# Validation loss decreased (0.539648 --> 0.539427).  Saving model ...
# 254 0.5478599071502686 0.841292142868042 0.5394266843795776 0.8522727489471436 0.586729884147644 0.8320209980010986
# Validation loss decreased (0.539427 --> 0.539206).  Saving model ...
# 255 0.5476202368736267 0.841292142868042 0.5392062067985535 0.8522727489471436 0.5865469574928284 0.8320209980010986
# Validation loss decreased (0.539206 --> 0.538987).  Saving model ...
# 256 0.547381579875946 0.841292142868042 0.5389869213104248 0.8579545617103577 0.5863651037216187 0.8320209980010986
# Validation loss decreased (0.538987 --> 0.538769).  Saving model ...
# 257 0.5471445322036743 0.841292142868042 0.5387688279151917 0.8579545617103577 0.5861839056015015 0.8320209980010986
# Validation loss decreased (0.538769 --> 0.538552).  Saving model ...
# ...
# Validation loss decreased (0.489506 --> 0.489482).  Saving model ...
# 915 0.4822084903717041 0.8890449404716492 0.4894820749759674 0.8693181872367859 0.5389180779457092 0.8582677245140076
# Validation loss decreased (0.489482 --> 0.489459).  Saving model ...
# 916 0.4821634888648987 0.8890449404716492 0.4894588589668274 0.8693181872367859 0.5388887524604797 0.8582677245140076
# Validation loss decreased (0.489459 --> 0.489436).  Saving model ...
# 917 0.4821186065673828 0.8890449404716492 0.4894355833530426 0.8693181872367859 0.5388588309288025 0.8582677245140076
# Validation loss decreased (0.489436 --> 0.489413).  Saving model ...
# 918 0.4820738732814789 0.8890449404716492 0.4894125163555145 0.8693181872367859 0.5388295650482178 0.8582677245140076
# Validation loss decreased (0.489413 --> 0.489389).  Saving model ...
# 919 0.4820288419723511 0.8890449404716492 0.48938918113708496 0.8693181872367859 0.5387998819351196 0.8582677245140076
# Validation loss decreased (0.489003 --> 0.488981).  Saving model ...
# 937 0.4812341630458832 0.8890449404716492 0.4889810085296631 0.8693181872367859 0.5382787585258484 0.8582677245140076
# Validation loss decreased (0.488981 --> 0.488959).  Saving model ...
# 938 0.48119068145751953 0.8890449404716492 0.4889587461948395 0.8693181872367859 0.5382500290870667 0.8582677245140076
# Validation loss decreased (0.488959 --> 0.488937).  Saving model ...
# 939 0.4811471104621887 0.8890449404716492 0.4889366626739502 0.8693181872367859 0.5382219552993774 0.8582677245140076
# Validation loss decreased (0.488937 --> 0.488915).  Saving model ...
# 940 0.48110347986221313 0.8890449404716492 0.4889147877693176 0.8693181872367859 0.5381937623023987 0.8582677245140076
# Validation loss decreased (0.488915 --> 0.488893).  Saving model ...
# 941 0.4810603857040405 0.8890449404716492 0.488892525434494 0.8693181872367859 0.5381647944450378 0.8582677245140076
# Validation loss decreased (0.488893 --> 0.488871).  Saving model ...
# 942 0.48101678490638733 0.8890449404716492 0.4888705313205719 0.8693181872367859 0.538136899471283 0.8582677245140076
# Validation loss decreased (0.488871 --> 0.488849).  Saving model ...
# 943 0.48097333312034607 0.8890449404716492 0.4888485074043274 0.8693181872367859 0.538108229637146 0.8582677245140076
# Validation loss decreased (0.488849 --> 0.488827).  Saving model ...
# 944 0.4809300899505615 0.8890449404716492 0.48882684111595154 0.8693181872367859 0.538080096244812 0.8582677245140076
# Validation loss decreased (0.488827 --> 0.488805).  Saving model ...
# 945 0.48088663816452026 0.8890449404716492 0.4888049066066742 0.8693181872367859 0.5380518436431885 0.8582677245140076
# Validation loss decreased (0.488805 --> 0.488783).  Saving model ...
# 946 0.4808439314365387 0.8890449404716492 0.4887830317020416 0.8693181872367859 0.538023829460144 0.8582677245140076
# Validation loss decreased (0.488783 --> 0.488761).  Saving model ...
# 947 0.48080042004585266 0.8890449404716492 0.4887613356113434 0.8693181872367859 0.5379959940910339 0.8582677245140076
# Validation loss decreased (0.488761 --> 0.488740).  Saving model ...
# 948 0.48075762391090393 0.8890449404716492 0.4887396991252899 0.8693181872367859 0.5379677414894104 0.8582677245140076
# Validation loss decreased (0.488740 --> 0.488718).  Saving model ...
# 949 0.48071467876434326 0.8890449404716492 0.4887179136276245 0.8693181872367859 0.5379394888877869 0.8582677245140076
# Validation loss decreased (0.488718 --> 0.488696).  Saving model ...
# 950 0.48067203164100647 0.8890449404716492 0.48869648575782776 0.8693181872367859 0.5379114151000977 0.8582677245140076
# Validation loss decreased (0.488696 --> 0.488675).  Saving model ...
# 951 0.4806289076805115 0.8890449404716492 0.48867493867874146 0.8693181872367859 0.5378838777542114 0.8582677245140076
# Validation loss decreased (0.488675 --> 0.488653).  Saving model ...
# 952 0.48058605194091797 0.8890449404716492 0.4886534512042999 0.8693181872367859 0.5378562808036804 0.8608924150466919
# Validation loss decreased (0.488653 --> 0.488632).  Saving model ...
# 953 0.48054325580596924 0.8890449404716492 0.4886319041252136 0.8693181872367859 0.5378285050392151 0.8608924150466919
# Validation loss decreased (0.488632 --> 0.488610).  Saving model ...
# 954 0.4805004596710205 0.8890449404716492 0.4886104464530945 0.8693181872367859 0.5378008484840393 0.8608924150466919
# Validation loss decreased (0.488610 --> 0.488589).  Saving model ...
# 955 0.48045819997787476 0.8890449404716492 0.4885890483856201 0.8693181872367859 0.5377728343009949 0.8608924150466919
# Validation loss decreased (0.488589 --> 0.488568).  Saving model ...
# 956 0.48041513562202454 0.8890449404716492 0.4885677695274353 0.8693181872367859 0.5377453565597534 0.8608924150466919
# Validation loss decreased (0.488568 --> 0.488546).  Saving model ...
# 957 0.4803728461265564 0.8890449404716492 0.4885464906692505 0.8693181872367859 0.5377177596092224 0.8608924150466919
# Validation loss decreased (0.488546 --> 0.488525).  Saving model ...
# 958 0.4803301692008972 0.8890449404716492 0.48852530121803284 0.8693181872367859 0.5376900434494019 0.8608924150466919
# Validation loss decreased (0.488525 --> 0.488504).  Saving model ...
# 959 0.48028767108917236 0.8890449404716492 0.48850417137145996 0.8693181872367859 0.5376625061035156 0.8608924150466919
# Validation loss decreased (0.488504 --> 0.488483).  Saving model ...
# 960 0.4802455008029938 0.8890449404716492 0.4884830117225647 0.8693181872367859 0.5376349687576294 0.8608924150466919
# Validation loss decreased (0.488483 --> 0.488462).  Saving model ...
# 961 0.4802030622959137 0.8890449404716492 0.48846185207366943 0.8693181872367859 0.5376076102256775 0.8608924150466919
# Validation loss decreased (0.488462 --> 0.488441).  Saving model ...
# 962 0.480160653591156 0.8890449404716492 0.4884406626224518 0.8693181872367859 0.537580668926239 0.8608924150466919
# Validation loss decreased (0.488441 --> 0.488420).  Saving model ...
# 963 0.4801187217235565 0.8890449404716492 0.48841968178749084 0.8693181872367859 0.5375531315803528 0.8608924150466919
# Validation loss decreased (0.488420 --> 0.488399).  Saving model ...
# 964 0.4800766110420227 0.8890449404716492 0.48839884996414185 0.8693181872367859 0.5375258922576904 0.8608924150466919
# Validation loss decreased (0.488399 --> 0.488378).  Saving model ...
# 965 0.4800340533256531 0.8890449404716492 0.4883778691291809 0.8693181872367859 0.5374984741210938 0.8608924150466919
# Validation loss decreased (0.488378 --> 0.488357).  Saving model ...
# 966 0.4799923300743103 0.8890449404716492 0.4883571267127991 0.8693181872367859 0.5374714732170105 0.8608924150466919
# Validation loss decreased (0.488357 --> 0.488336).  Saving model ...
# 967 0.47995033860206604 0.8890449404716492 0.48833632469177246 0.8693181872367859 0.5374438166618347 0.8608924150466919
# Validation loss decreased (0.488336 --> 0.488316).  Saving model ...
# 968 0.47990795969963074 0.8904494643211365 0.4883155822753906 0.8693181872367859 0.537416934967041 0.8608924150466919
# Validation loss decreased (0.488316 --> 0.488295).  Saving model ...
# 969 0.47986650466918945 0.8904494643211365 0.4882947504520416 0.8693181872367859 0.5373901128768921 0.8608924150466919
# Validation loss decreased (0.488295 --> 0.488274).  Saving model ...
# 987 0.47912126779556274 0.8904494643211365 0.4879295825958252 0.8693181872367859 0.536910891532898 0.8608924150466919
# Validation loss decreased (0.487930 --> 0.487910).  Saving model ...
# 988 0.47908005118370056 0.8904494643211365 0.48790979385375977 0.8693181872367859 0.5368845462799072 0.8608924150466919
# Validation loss decreased (0.487910 --> 0.487890).  Saving model ...
# 989 0.47903919219970703 0.8904494643211365 0.48788967728614807 0.8693181872367859 0.5368582010269165 0.8608924150466919
# Validation loss decreased (0.487890 --> 0.487870).  Saving model ...
# 990 0.4789985120296478 0.8904494643211365 0.48786988854408264 0.8693181872367859 0.5368320941925049 0.8608924150466919
# Validation loss decreased (0.487870 --> 0.487850).  Saving model ...
# 991 0.47895801067352295 0.8904494643211365 0.487850159406662 0.8693181872367859 0.5368059277534485 0.8608924150466919
# Validation loss decreased (0.487850 --> 0.487830).  Saving model ...
# 992 0.47891730070114136 0.8904494643211365 0.4878304898738861 0.8693181872367859 0.5367802381515503 0.8608924150466919
# Validation loss decreased (0.487830 --> 0.487811).  Saving model ...
# 993 0.4788760244846344 0.8904494643211365 0.487810879945755 0.8693181872367859 0.5367540717124939 0.8608924150466919
# Validation loss decreased (0.487811 --> 0.487791).  Saving model ...
# 994 0.4788356423377991 0.8904494643211365 0.48779112100601196 0.8693181872367859 0.5367281436920166 0.8608924150466919
# Validation loss decreased (0.487791 --> 0.487771).  Saving model ...
# 995 0.47879520058631897 0.891853928565979 0.48777148127555847 0.8693181872367859 0.5367024540901184 0.8608924150466919
# Validation loss decreased (0.487771 --> 0.487752).  Saving model ...
# 996 0.47875452041625977 0.891853928565979 0.4877520501613617 0.8693181872367859 0.5366765260696411 0.8608924150466919
# Validation loss decreased (0.487752 --> 0.487733).  Saving model ...
# 997 0.4787140488624573 0.891853928565979 0.48773252964019775 0.8693181872367859 0.5366506576538086 0.8608924150466919
# Validation loss decreased (0.487733 --> 0.487713).  Saving model ...
# 998 0.47867363691329956 0.891853928565979 0.48771315813064575 0.8693181872367859 0.5366249680519104 0.8608924150466919
# Validation loss decreased (0.487713 --> 0.487694).  Saving model ...
# 999 0.47863370180130005 0.891853928565979 0.4876936972141266 0.8693181872367859 0.5365990996360779 0.8608924150466919
# <All keys matched successfully>

# %%
print(Precision(prediction, Y_train_tensor))
print(Precision(val_prediction, Y_valid_tensor))
print(Precision(test_prediction, Y_test_tensor))
# Out:
# [0.9570661783218384, 0.6535947918891907]
# [0.9489051103591919, 0.5897436141967773]
# [0.9344262480735779, 0.5657894611358643]

# %%
print(Recall(prediction, Y_train_tensor))
print(Recall(val_prediction, Y_valid_tensor))
print(Recall(test_prediction, Y_test_tensor))
# Out:
# [0.9098639488220215, 0.8064516186714172]
# [0.8904109597206116, 0.7666666507720947]
# [0.8962264060974121, 0.682539701461792]

# %%
print(Accuracy(prediction, Y_train_tensor))
print(Accuracy(val_prediction, Y_valid_tensor))
print(Accuracy(test_prediction, Y_test_tensor))
# Out:
# 0.891853928565979
# 0.8693181872367859
# 0.8608924150466919
